# %% [markdown]
# ## Регулярные выражения

# %% [markdown]
# https://tproger.ru/translations/regular-expression-python/

# %%
import re

# %% [markdown]
# # match
# ищет по заданному шаблону в начале строки

# %%
result = re.match('ab+c.', 'abcdefghijkabcabcd') # ищем по шаблону 'ab+c.' 
print(result) # совпадение найдено:
# Out:
# <_sre.SRE_Match object; span=(0, 4), match='abcd'>

# %%
print(result.group(0)) # выволмс найденное совпадение
# Out:
# abcd

# %%
result = re.match('abc.', 'abdefghijkabcabc')
print(result) # совпадение не найдено
# Out:
# None

# %% [markdown]
# ## Задание 1:
# Проверьте, начинаются ли строки c заглавной буквы и если да, то вывести эту заглавную букву. Придумайте свои примеры строк для проверки.

# %%
result = re.match("[A-Z]", "Xtz")
print(result)
# Out:
# <_sre.SRE_Match object; span=(0, 1), match='X'>

# %% [markdown]
# # search
# ищет по всей строке, возвращает только первое найденное совпадение

# %%
result = re.search('ab+c.', 'aefgabchijkabcabc') 
print(result)
# Out:
# <_sre.SRE_Match object; span=(4, 8), match='abch'>

# %% [markdown]
# ## Задание 2
# Проверьте, есть ли в строке вопросительный знак. Придумайте свои примеры для проверки.

# %%
result = re.search("\?", "12?")
print(result)
# Out:
# <_sre.SRE_Match object; span=(2, 3), match='?'>

# %% [markdown]
# # findall
# возвращает список всех найденных совпадений

# %%
result = re.findall('ab+c.', 'abcdefghijkabcabcxabc') 
print(result)
# Out:
# ['abcd', 'abca']

# %% [markdown]
# Вопросы:
# 1) почему нет последнего abc?
# 2) почему нет abcx?

# %% [markdown]
# ## Задание 3
# Вернуть список первых двух букв каждого слова в строке, состоящей из нескольких слов.

# %%
result = re.findall('(^\w{2}|\s+\w{2})', "Such Interesting task ")
print(result)
# Out:
# ['Su', ' In', ' ta']

# %% [markdown]
# # split
# разделяет строку по заданному шаблону

# %%
result = re.split(',', 'itsy, bitsy, teenie, weenie') 
print(result)
# Out:
# ['itsy', ' bitsy', ' teenie', ' weenie']

# %% [markdown]
# можно указать максимальное количество разбиений

# %%
result = re.split(',', 'itsy, bitsy, teenie, weenie', maxsplit = 2) 
print(result)
# Out:
# ['itsy', ' bitsy', ' teenie, weenie']

# %% [markdown]
# ## Задание 4
# Разбейте строку, состоящую из нескольких предложений, по точкам, но не более чем на 3 предложения.

# %%
text = """
Нашел он полон двор услуги;
К покойнику со всех сторон
Съезжались недруги и други,
Охотники до похорон.
Покойника похоронили.
Попы и гости ели, пили
И после важно разошлись,
Как будто делом занялись.
Вот наш Онегин — сельский житель,
Заводов, вод, лесов, земель
Хозяин полный, а досель
Порядка враг и расточитель,
И очень рад, что прежний путь
Переменил на что-нибудь."""
result = re.split('\.',text, maxsplit=2)
for line in result:
    print(line, "\n", end="*"*55)
# Out:
# Нашел он полон двор услуги;
# К покойнику со всех сторон
# Съезжались недруги и други,
# Охотники до похорон
# *******************************************************
# Покойника похоронили
# *******************************************************
# Попы и гости ели, пили
# И после важно разошлись,
# Как будто делом занялись.
# Вот наш Онегин — сельский житель,
# Заводов, вод, лесов, земель
# Хозяин полный, а досель
# Порядка враг и расточитель,
# И очень рад, что прежний путь
# Переменил на что-нибудь.
# *******************************************************

# %% [markdown]
# # sub
# ищет шаблон в строке и заменяет все совпадения на указанную подстроку
#
# параметры: (pattern, repl, string)

# %%
result = re.sub('a', 'b', 'abcabc')
print (result)
# Out:
# bbcbbc

# %% [markdown]
# ## Задание 5:
# Замените все цифры на звездочки.

# %%
result = re.sub("\d","*", "7253dvhfks0340921934uhgj34l4321")
print(result)
# Out:
# ****dvhfks**********uhgj**l****

# %% [markdown]
# # compile
# компилирует регулярное выражение в отдельный объект

# %%
# Пример: построение списка всех слов строки:
prog = re.compile('[А-Яа-яё\-]+')
prog.findall("Слова? Да, больше, ещё больше слов! Что-то ещё.")
# Out:
# ['Слова', 'Да', 'больше', 'ещё', 'больше', 'слов', 'Что-то', 'ещё']

# %% [markdown]
# ## Задание 6
# Для выбранной строки постройте список слов, которые длиннее трех символов.

# %%
result = re.findall("\w{4,}", text)
print(result)
# Out:
# ['Нашел', 'полон', 'двор', 'услуги', 'покойнику', 'всех', 'сторон', 'Съезжались', 'недруги', 'други', 'Охотники', 'похорон', 'Покойника', 'похоронили', 'Попы', 'гости', 'пили', 'после', 'важно', 'разошлись', 'будто', 'делом', 'занялись', 'Онегин', 'сельский', 'житель', 'Заводов', 'лесов', 'земель', 'Хозяин', 'полный', 'досель', 'Порядка', 'враг', 'расточитель', 'очень', 'прежний', 'путь', 'Переменил', 'нибудь']

# %% [markdown]
# ## Задание 7
# Вернуть первое слово строки

# %%
result = re.match("\s*\w+", "Первое слово строки.")
print(result)
result = re.match("\s*\w+", text)
print(result)
# Out:
# <_sre.SRE_Match object; span=(0, 6), match='Первое'>
# <_sre.SRE_Match object; span=(0, 6), match='\nНашел'>

# %% [markdown]
# ## Задание 8
# Вернуть список доменов (@gmail.com) из списка адресов электронной почты:
#
# abc.test@gmail.com, xyz@test.in, test.first@analyticsvidhya.com, first.test@rest.biz

# %%
domains  = """abc.test@gmail.com, xyz@test.in, test.first@analyticsvidhya.com, first.test@rest.biz"""
domains = re.split(", ", domains)
for domain in domains:
    print(re.match("^.+@gmail.com$", domain))
# Out:
# <_sre.SRE_Match object; span=(0, 18), match='abc.test@gmail.com'>
# None
# None
# None

# %% [markdown]
# ## Токенизация
#
#
# Самый наивный способ токенизировать текст -- разделить с помощью split. Но split упускает очень много всего, например, банально не отделяет пунктуацию от слов. Кроме этого, есть ещё много менее тривиальных проблем. Поэтому лучше использовать готовые токенизаторы.

# %% [markdown]
# ## Задание 9
#
# Откройте и запишите в одну текстовую строку файл alice.txt.
#
# Ответьте на вопросы:
#
#     Сколько всего символов в файле?
#     Какой текст написан в последней строке файла? (Подсказка: в какой переменной содержится эта строка?)

# %%
s = ''
with open("alice.txt") as infile:
    for line in infile:
        s += line.strip() + ' '
    print("text size:", len(s))
    print("last sentence:", s[-151:])
# Out:
# text size: 168061
# last sentence: Алиса послушно вскочила и побежала домой, но и по дороге она все думала, какой же это был чудесный сон - сон, который, наверно, никогда не забудешь...

# %% [markdown]
# ## Задание 10
#
# Создайте и скомпилируйте регулярное выражения для разбиения полученной строки на токены. Не забудьте про дефис и букву ё.
#
# Найдите все токены с помощью этого регулярного выражения, ответьте на вопросы:
#
#     Сколько токенов получилось?
#     Какой токен первый?
#     Какой токен последний?

# %%
prog = re.compile(r'[А-Яа-яё]+')
l1 = prog.findall(s.lower())
print("tokens length:", len(l1))
print("first token:", l1[0])
print("last token:", l1[-1])
# Out:
# tokens length: 26575
# first token: льюис
# last token: забудешь

# %% [markdown]
# ## Токенизация в nltk

# %%
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/ilavasilevic/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
example = 'Но не каждый хочет что-то исправлять:('
word_tokenize(example)
# Out:
# ['Но', 'не', 'каждый', 'хочет', 'что-то', 'исправлять', ':', '(']

# %%
from nltk import tokenize
dir(tokenize)[:16]
# Out:
# ['BlanklineTokenizer',
#  'LineTokenizer',
#  'MWETokenizer',
#  'PunktSentenceTokenizer',
#  'RegexpTokenizer',
#  'ReppTokenizer',
#  'SExprTokenizer',
#  'SpaceTokenizer',
#  'StanfordSegmenter',
#  'TabTokenizer',
#  'TextTilingTokenizer',
#  'ToktokTokenizer',
#  'TreebankWordTokenizer',
#  'TweetTokenizer',
#  'WhitespaceTokenizer',
#  'WordPunctTokenizer']

# %% [markdown]
# Они умеют выдавать индексы начала и конца каждого токена:

# %%
wh_tok = tokenize.WhitespaceTokenizer()
list(wh_tok.span_tokenize(example))
# Out:
# [(0, 2), (3, 5), (6, 12), (13, 18), (19, 25), (26, 38)]

# %% [markdown]
# (если вам было интересно, зачем вообще включать в модуль токенизатор, который работает как .split() :))
#
# Некторые токенизаторы ведут себя специфично:

# %%
tokenize.TreebankWordTokenizer().tokenize("don't stop me")
# Out:
# ['do', "n't", 'stop', 'me']

# %% [markdown]
# Для некоторых задач это может быть полезно.
#
# А некоторые -- вообще не для текста на естественном языке (не очень понятно, зачем это в nltk :)):

# %%
tokenize.SExprTokenizer().tokenize("(a (b c)) d e (f)")
# Out:
# ['(a (b c))', 'd', 'e', '(f)']

# %% [markdown]
# ## Стоп-слова и пунктуация
#
# Стоп-слова -- это слова, которые часто встречаются практически в любом тексте и ничего интересного не говорят о конретном документе, то есть играют роль шума. Поэтому их принято убирать. По той же причине убирают и пунктуацию.

# %%
# у вас здесь, вероятно, выскочит ошибка и надо будет загрузить стоп слова (в тексте ошибки написано, как)
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
print(stopwords.words('russian'))
# Out:
# ['и', 'в', 'во', 'не', 'что', 'он', 'на', 'я', 'с', 'со', 'как', 'а', 'то', 'все', 'она', 'так', 'его', 'но', 'да', 'ты', 'к', 'у', 'же', 'вы', 'за', 'бы', 'по', 'только', 'ее', 'мне', 'было', 'вот', 'от', 'меня', 'еще', 'нет', 'о', 'из', 'ему', 'теперь', 'когда', 'даже', 'ну', 'вдруг', 'ли', 'если', 'уже', 'или', 'ни', 'быть', 'был', 'него', 'до', 'вас', 'нибудь', 'опять', 'уж', 'вам', 'ведь', 'там', 'потом', 'себя', 'ничего', 'ей', 'может', 'они', 'тут', 'где', 'есть', 'надо', 'ней', 'для', 'мы', 'тебя', 'их', 'чем', 'была', 'сам', 'чтоб', 'без', 'будто', 'чего', 'раз', 'тоже', 'себе', 'под', 'будет', 'ж', 'тогда', 'кто', 'этот', 'того', 'потому', 'этого', 'какой', 'совсем', 'ним', 'здесь', 'этом', 'один', 'почти', 'мой', 'тем', 'чтобы', 'нее', 'сейчас', 'были', 'куда', 'зачем', 'всех', 'никогда', 'можно', 'при', 'наконец', 'два', 'об', 'другой', 'хоть', 'после', 'над', 'больше', 'тот', 'через', 'эти', 'нас', 'про', 'всего', 'них', 'какая', 'много', 'разве', 'три', 'эту', 'моя', 'впрочем', 'хорошо', 'свою', 'этой', 'перед', 'иногда', 'лучше', 'чуть', 'том', 'нельзя', 'такой', 'им', 'более', 'всегда', 'конечно', 'всю', 'между']
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/ilavasilevic/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from string import punctuation
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
noise = stopwords.words('russian') + list(punctuation)

# %% [markdown]
# ## Лемматизация
#
# Лемматизация – это сведение разных форм одного слова к начальной форме – лемме. Почему это хорошо?
#
#     Во-первых, мы хотим рассматривать как отдельную фичу каждое слово, а не каждую его отдельную форму.
#     Во-вторых, некоторые стоп-слова стоят только в начальной форме, и без лематизации выкидываем мы только её.
#
# Для русского есть два хороших лемматизатора: mystem и pymorphy:
# Mystem
#
# Как с ним работать:
#
#     можно скачать mystem и запускать из терминала с разными параметрами
#     pymystem3 - обертка для питона, работает медленнее, но это удобно

# %%
from pymystem3 import Mystem
mystem_analyzer = Mystem()

# %% [markdown]
# Мы инициализировали Mystem c дефолтными параметрами. А вообще параметры есть такие:
#
#     mystem_bin - путь к mystem, если их несколько
#     grammar_info - нужна ли грамматическая информация или только леммы (по дефолту нужна)
#     disambiguation - нужно ли снятие омонимии - дизамбигуация (по дефолту нужна)
#     entire_input - нужно ли сохранять в выводе все (пробелы всякие, например), или можно выкинуть (по дефолту оставляется все)
#
# Методы Mystem принимают строку, токенизатор вшит внутри. Можно, конечно, и пословно анализировать, но тогда он не сможет учитывать контекст.
#
# Можно просто лемматизировать текст:

# %%
print(example)
print(mystem_analyzer.lemmatize(example))
# Out:
# Но не каждый хочет что-то исправлять:(
# ['но', ' ', 'не', ' ', 'каждый', ' ', 'хотеть', ' ', 'что-то', ' ', 'исправлять', ':(\n']

# %% [markdown]
# А можно получить грамматическую информацию:

# %%
mystem_analyzer.analyze(example)
# Out:
# [{'analysis': [{'lex': 'но', 'wt': 0.9998906299, 'gr': 'CONJ='}],
#   'text': 'Но'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'не', 'wt': 1, 'gr': 'PART='}], 'text': 'не'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'каждый',
#     'wt': 0.9985975799,
#     'gr': 'APRO=(вин,ед,муж,неод|им,ед,муж)'}],
#   'text': 'каждый'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'хотеть',
#     'wt': 1,
#     'gr': 'V,несов,пе=непрош,ед,изъяв,3-л'}],
#   'text': 'хочет'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'что-то', 'wt': 1, 'gr': 'SPRO,ед,сред,неод=(вин|им)'}],
#   'text': 'что-то'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'исправлять', 'wt': 1, 'gr': 'V,пе=инф,несов'}],
#   'text': 'исправлять'},
#  {'text': ':(\n'}]

# %% [markdown]
# Используем лемматизатор майстема в качестве токенизатора.

# %%
text
# Out:
# '\nНашел он полон двор услуги;\nК покойнику со всех сторон\nСъезжались недруги и други,\nОхотники до похорон.\nПокойника похоронили.\nПопы и гости ели, пили\nИ после важно разошлись,\nКак будто делом занялись.\nВот наш Онегин — сельский житель,\nЗаводов, вод, лесов, земель\nХозяин полный, а досель\nПорядка враг и расточитель,\nИ очень рад, что прежний путь\nПеременил на что-нибудь.'

# %%
import re
def my_preproc(text):
    text = re.sub('[{}]'.format(punctuation), '', text)
    text = mystem_analyzer.analyze(text)
    return [word for word in text if word not in stopwords.words('russian') + [' ', '\n']]
print(my_preproc(text))
# Out:
# [{'text': '\n'}, {'analysis': [{'lex': 'находить', 'wt': 1, 'gr': 'V=прош,ед,изъяв,муж,сов,пе'}], 'text': 'Нашел'}, {'text': ' '}, {'analysis': [{'lex': 'он', 'wt': 1, 'gr': 'SPRO,ед,3-л,муж=им'}], 'text': 'он'}, {'text': ' '}, {'analysis': [{'lex': 'полный', 'wt': 0.993007543, 'gr': 'A=ед,кр,муж'}], 'text': 'полон'}, {'text': ' '}, {'analysis': [{'lex': 'двор', 'wt': 1, 'gr': 'S,муж,неод=(вин,ед|им,ед)'}], 'text': 'двор'}, {'text': ' '}, {'analysis': [{'lex': 'услуга', 'wt': 1, 'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}], 'text': 'услуги'}, {'text': '\n'}, {'analysis': [{'lex': 'к', 'wt': 0.9999551798, 'gr': 'PR='}], 'text': 'К'}, {'text': ' '}, {'analysis': [{'lex': 'покойник', 'wt': 1, 'gr': 'S,муж,од=дат,ед'}], 'text': 'покойнику'}, {'text': ' '}, {'analysis': [{'lex': 'со', 'wt': 1, 'gr': 'PR='}], 'text': 'со'}, {'text': ' '}, {'analysis': [{'lex': 'весь', 'wt': 0.6929341789, 'gr': 'APRO=(пр,мн|род,мн|вин,мн,од)'}], 'text': 'всех'}, {'text': ' '}, {'analysis': [{'lex': 'сторона', 'wt': 1, 'gr': 'S,жен,неод=род,мн'}], 'text': 'сторон'}, {'text': '\n'}, {'analysis': [{'lex': 'съезжаться', 'wt': 1, 'gr': 'V,нп=прош,мн,изъяв,несов'}], 'text': 'Съезжались'}, {'text': ' '}, {'analysis': [{'lex': 'недруг', 'wt': 1, 'gr': 'S,муж,од=им,мн'}], 'text': 'недруги'}, {'text': ' '}, {'analysis': [{'lex': 'и', 'wt': 0.9999770357, 'gr': 'CONJ='}], 'text': 'и'}, {'text': ' '}, {'analysis': [{'lex': 'друг', 'wt': 0.1922681551, 'qual': 'bastard', 'gr': 'S,муж,од=им,мн'}], 'text': 'други'}, {'text': '\n'}, {'analysis': [{'lex': 'охотник', 'wt': 1, 'gr': 'S,муж,од=им,мн'}], 'text': 'Охотники'}, {'text': ' '}, {'analysis': [{'lex': 'до', 'wt': 0.9994975359, 'gr': 'PR='}], 'text': 'до'}, {'text': ' '}, {'analysis': [{'lex': 'похороны', 'wt': 1, 'gr': 'S,мн,неод=род'}], 'text': 'похорон'}, {'text': '\n'}, {'analysis': [{'lex': 'покойник', 'wt': 1, 'gr': 'S,муж,од=(вин,ед|род,ед)'}], 'text': 'Покойника'}, {'text': ' '}, {'analysis': [{'lex': 'похоронить', 'wt': 1, 'gr': 'V,сов,пе=прош,мн,изъяв'}], 'text': 'похоронили'}, {'text': '\n'}, {'analysis': [{'lex': 'поп', 'wt': 0.8426030975, 'gr': 'S,муж,од=им,мн'}], 'text': 'Попы'}, {'text': ' '}, {'analysis': [{'lex': 'и', 'wt': 0.9999770357, 'gr': 'CONJ='}], 'text': 'и'}, {'text': ' '}, {'analysis': [{'lex': 'гость', 'wt': 0.9949936629, 'gr': 'S,муж,од=им,мн'}], 'text': 'гости'}, {'text': ' '}, {'analysis': [{'lex': 'есть', 'wt': 0.7737144486, 'gr': 'V,несов,пе=прош,мн,изъяв'}], 'text': 'ели'}, {'text': ' '}, {'analysis': [{'lex': 'пить', 'wt': 0.9975956078, 'gr': 'V,несов,пе=прош,мн,изъяв'}], 'text': 'пили'}, {'text': '\n'}, {'analysis': [{'lex': 'и', 'wt': 0.9999770357, 'gr': 'CONJ='}], 'text': 'И'}, {'text': ' '}, {'analysis': [{'lex': 'после', 'wt': 0.02242117654, 'gr': 'ADV='}], 'text': 'после'}, {'text': ' '}, {'analysis': [{'lex': 'важно', 'wt': 0.42205742, 'gr': 'ADV='}], 'text': 'важно'}, {'text': ' '}, {'analysis': [{'lex': 'расходиться', 'wt': 1, 'gr': 'V,нп=прош,мн,изъяв,сов'}], 'text': 'разошлись'}, {'text': '\n'}, {'analysis': [{'lex': 'как', 'wt': 0.3756069802, 'gr': 'ADVPRO='}], 'text': 'Как'}, {'text': ' '}, {'analysis': [{'lex': 'будто', 'wt': 0.6150145335, 'gr': 'PART='}], 'text': 'будто'}, {'text': ' '}, {'analysis': [{'lex': 'дело', 'wt': 1, 'gr': 'S,сред,неод=твор,ед'}], 'text': 'делом'}, {'text': ' '}, {'analysis': [{'lex': 'заниматься', 'wt': 1, 'gr': 'V,нп=прош,мн,изъяв,сов'}], 'text': 'занялись'}, {'text': '\n'}, {'analysis': [{'lex': 'вот', 'wt': 0.9998923304, 'gr': 'PART='}], 'text': 'Вот'}, {'text': ' '}, {'analysis': [{'lex': 'наш', 'wt': 1, 'gr': 'APRO=(вин,ед,муж,неод|им,ед,муж)'}], 'text': 'наш'}, {'text': ' '}, {'analysis': [{'lex': 'онегин', 'wt': 1, 'gr': 'S,фам,муж,од=им,ед'}], 'text': 'Онегин'}, {'text': ' — '}, {'analysis': [{'lex': 'сельский', 'wt': 1, 'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}], 'text': 'сельский'}, {'text': ' '}, {'analysis': [{'lex': 'житель', 'wt': 1, 'gr': 'S,муж,од=им,ед'}], 'text': 'житель'}, {'text': '\n'}, {'analysis': [{'lex': 'зав ...

# %% [markdown]
# ## Pymorphy
#
# Это модуль на питоне, довольно быстрый и с кучей функций.

# %%
from pymorphy2 import MorphAnalyzer
pymorphy2_analyzer = MorphAnalyzer()

# %% [markdown]
# pymorphy2 работает с отдельными словами. Если дать ему на вход предложение - он его просто не лемматизирует, т.к. не понимает

# %%
ana = pymorphy2_analyzer.parse(example)
ana
# Out:
# [Parse(word='но не каждый хочет что-то исправлять:(', tag=OpencorporaTag('UNKN'), normal_form='но не каждый хочет что-то исправлять:(', score=1.0, methods_stack=((<UnknAnalyzer>, 'Но не каждый хочет что-то исправлять:('),))]

# %%
ana[0].normal_form

def my_preproc_(text):
    text = re.sub('[{}]'.format(punctuation), '', text)
    words = word_tokenize(text)
#     return [word for word in words if word not in stopwords.words('russian') + [' ', '\n']]
    return [pymorphy2_analyzer.parse(word)[0].normal_form for word in words if word not in stopwords.words('russian') + [' ', '\n']]
print(my_preproc(example))
print(my_preproc_(example))
# Out:
# [{'analysis': [{'lex': 'но', 'wt': 0.9998906299, 'gr': 'CONJ='}], 'text': 'Но'}, {'text': ' '}, {'analysis': [{'lex': 'не', 'wt': 1, 'gr': 'PART='}], 'text': 'не'}, {'text': ' '}, {'analysis': [{'lex': 'каждый', 'wt': 0.9985975799, 'gr': 'APRO=(вин,ед,муж,неод|им,ед,муж)'}], 'text': 'каждый'}, {'text': ' '}, {'analysis': [{'lex': 'хотеть', 'wt': 1, 'gr': 'V,несов,пе=непрош,ед,изъяв,3-л'}], 'text': 'хочет'}, {'text': ' '}, {'analysis': [{'lex': 'чтото', 'wt': 1, 'qual': 'bastard', 'gr': 'S,имя,муж,од=(пр,мн|пр,ед|вин,мн|вин,ед|дат,мн|дат,ед|род,мн|род,ед|твор,мн|твор,ед|им,мн|им,ед)'}], 'text': 'чтото'}, {'text': ' '}, {'analysis': [{'lex': 'исправлять', 'wt': 1, 'gr': 'V,пе=инф,несов'}], 'text': 'исправлять'}, {'text': '\n'}]
# ['но', 'каждый', 'хотеть', 'чтоть', 'исправлять']

# %% [markdown]
# А теперь напишите аналогичную функцию для лемматизации с pymorphy2:

# %% [markdown]
# ## mystem vs. pymorphy
#
# 1) Mystem работает невероятно медленно под windows на больших текстах.
#
# 2) Снятие омонимии. Mystem умеет снимать омонимию по контексту (хотя не всегда преуспевает), pymorphy2 берет на вход одно слово и соответственно вообще не умеет дизамбигуировать по контексту:

# %%
homonym1 = 'За время обучения я прослушал больше сорока курсов.'
homonym2 = 'Сорока своровала блестящее украшение со стола.'
mystem_analyzer = Mystem() # инициализирую объект с дефолтными параметрами

print(mystem_analyzer.analyze(homonym1)[-5])
print(mystem_analyzer.analyze(homonym2)[0])
# Out:
# {'analysis': [{'lex': 'сорок', 'wt': 0.8710292664, 'gr': 'NUM=(пр|дат|род|твор)'}], 'text': 'сорока'}
# {'analysis': [{'lex': 'сорока', 'wt': 0.1210970041, 'gr': 'S,жен,од=им,ед'}], 'text': 'Сорока'}

# %% [markdown]
# ## Задание 11
#
# Используя стандартные инструменты переведите корпус alice.txt в формат CoNLL-U.
# Используйте следующие колонки:
#     1. Номер предложения в тексте
#     2. Токен в том виде, в котором он встретился в тексте
#     3. Лемма токена
#     4. POS-таг токена
#     5. Вектор грамматических значений токена
#     6. Целевая метка (сделайте метку везде OUT)

# %%
from nltk import tag

# %%
text1 = re.split('[.]', s)

# %%
text2 = []
for sentence in text1:
    spliter = re.split('! ', sentence)
    if len(spliter) == 1:
        text2.append(sentence)
    else:
        for i in range(len(spliter)):
            text2.append(spliter[i])

# %%
text3 = [word for word in filter(lambda a: a != '', text2)]

# %%
def CoNll(text):
    conll = []
    mark = 'OUT'
    number = 1
    for sentence in text:
        sentence = sentence.lower()
        analysis = mystem_analyzer.analyze(sentence)
        analysis_ = [word for word in analysis if word.get('text') not in stopwords.words('russian') + [' ', '\n', ' - ', ', '] + list(punctuation)]
        
        for word in analysis_:
            
            decision = word.get('analysis') is None
            
            if decision == True:
                
                continue
            
            else:
                
                mix = []
                mix.append(number)
                mix.append(word.get('text'))
                token = word_tokenize(word.get('text'))
                try:
                    mix.append(word.get('analysis')[0].get('lex'))
                    
                except:
                    
                    continue
                    
                mix.append(pos_tag(token,lang='rus')[0][1])
                mix.append(word.get('analysis')[0].get('gr'))
                mix.append(mark)
                conll.append(mix)
        
        number += 1
        
    return conll

# %%
cobllll = CoNll(text3)

# %%
cobllll
# Out:
# [[1, 'льюис', 'льюис', 'S', 'S,гео,муж,неод=(вин,ед|им,ед)', 'OUT'],
#  [1, 'кэрролл', 'кэрролл', 'S', 'S,фам,муж,од=им,ед', 'OUT'],
#  [2, 'алиса', 'алиса', 'S', 'S,имя,жен,од=им,ед', 'OUT'],
#  [2, 'стране', 'страна', 'S', 'S,жен,неод=(пр,ед|дат,ед)', 'OUT'],
#  [2, 'чудес', 'чудо', 'S', 'S,сред,неод=род,мн', 'OUT'],
#  [2, 'пересказ', 'пересказ', 'S', 'S,муж,неод=(вин,ед|им,ед)', 'OUT'],
#  [2,
#   'английского',
#   'английский',
#   'A=m',
#   'A=(вин,ед,полн,муж,од|род,ед,полн,муж|род,ед,полн,сред)',
#   'OUT'],
#  [2, 'бориса', 'борис', 'S', 'S,имя,муж,од=(вин,ед|род,ед)', 'OUT'],
#  [2, 'заходера', 'заходер', 'S', 'S,муж,од=(вин,ед|род,ед)', 'OUT'],
#  [2, 'глава', 'глава', 'S', 'S,муж,од=им,ед', 'OUT'],
#  [2, 'никакая', 'никакой', 'A-PRO=f', 'APRO=им,ед,жен', 'OUT'],
#  [2,
#   'которой',
#   'который',
#   'A-PRO=f',
#   'APRO=(пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен)',
#   'OUT'],
#  [2, 'менее', 'менее', 'ADV', 'ADV=', 'OUT'],
#  [2, 'кое-что', 'кое-что', 'S-PRO', 'SPRO,ед,сред,неод=(вин|им)', 'OUT'],
#  [2, 'узнать', 'узнавать', 'V', 'V,пе=инф,сов', 'OUT'],
#  [2, 'свете', 'свет', 'S', 'S,ед,муж,неод=пр', 'OUT'],
#  [2, 'ненавижу', 'ненавидеть', 'V', 'V,несов,пе=непрош,ед,изъяв,1-л', 'OUT'],
#  [2, 'обман', 'обман', 'S', 'S,муж,неод=(вин,ед|им,ед)', 'OUT'],
#  [2, 'люблю', 'любить', 'V', 'V,несов,пе=непрош,ед,изъяв,1-л', 'OUT'],
#  [2, 'честность', 'честность', 'S', 'S,жен,неод=(вин,ед|им,ед)', 'OUT'],
#  [2, 'сразу', 'сразу', 'ADV', 'ADV=', 'OUT'],
#  [2, 'честно', 'честно', 'ADV', 'ADV=', 'OUT'],
#  [2,
#   'признаюсь',
#   'признаваться',
#   'V',
#   'V,нп=(непрош,ед,изъяв,1-л,несов|непрош,ед,изъяв,1-л,сов)',
#   'OUT'],
#  [2, 'немножко', 'немножко', 'ADV', 'ADV=', 'OUT'],
#  [2, 'обманул', 'обманывать', 'V', 'V,пе=прош,ед,изъяв,муж,сов', 'OUT'],
#  [2, 'самом', 'самый', 'A-PRO=m', 'APRO=(пр,ед,муж|пр,ед,сред)', 'OUT'],
#  [2, 'деле', 'дело', 'S', 'S,сред,неод=пр,ед', 'OUT'],
#  [2, 'это', 'это', 'S-PRO', 'SPRO,ед,сред,неод=(вин|им)', 'OUT'],
#  [2, 'никакая', 'никакой', 'A-PRO=f', 'APRO=им,ед,жен', 'OUT'],
#  [2, 'глава', 'глава', 'S', 'S,жен,неод=им,ед', 'OUT'],
#  [2, 'никакая', 'никакой', 'A-PRO=f', 'APRO=им,ед,жен', 'OUT'],
#  [2, 'глава', 'глава', 'S', 'S,жен,неод=им,ед', 'OUT'],
#  [2, 'это', 'это', 'S-PRO', 'SPRO,ед,сред,неод=(вин|им)', 'OUT'],
#  [2, 'просто-напросто', 'просто-напросто', 'ADV', 'ADV=', 'OUT'],
#  [3, 'думаете', 'думать', 'V', 'V,несов,нп=непрош,мн,изъяв,2-л', 'OUT'],
#  [3, 'сказал', 'сказать', 'V', 'V,сов,пе=прош,ед,изъяв,муж', 'OUT'],
#  [3, 'подождите', 'подождать', 'V', 'V,сов,пе=мн,пов,2-л', 'OUT'],
#  [4, 'дочитаете', 'дочитывать', 'V', 'V=непрош,мн,изъяв,2-л,сов', 'OUT'],
#  [4, 'конца', 'конец', 'S', 'S,муж,неод=род,ед', 'OUT'],
#  [4,
#   'узнаете',
#   'узнавать',
#   'V',
#   'V,пе=(непрош,мн,изъяв,2-л,несов|непрош,мн,изъяв,2-л,сов)',
#   'OUT'],
#  [5, 'дочитаете', 'дочитывать', 'V', 'V=непрош,мн,изъяв,2-л,сов', 'OUT'],
#  [5, 'дело', 'дело', 'S', 'S,сред,неод=(вин,ед|им,ед)', 'OUT'],
#  [5, 'ваше', 'ваш', 'A-PRO=n', 'APRO=(вин,ед,сред|им,ед,сред)', 'OUT'],
#  [6, 'наверняка', 'наверняка', 'PART', 'ADV,вводн=', 'OUT'],
#  [7, 'сумеете', 'суметь', 'V', 'V,сов,нп=непрош,мн,изъяв,2-л', 'OUT'],
#  [7, 'правильно', 'правильно', 'ADV', 'ADV=', 'OUT'],
#  [7, 'прочитать', 'прочитывать', 'V', 'V=инф,сов', 'OUT'],
#  [7, 'книжку', 'книжка', 'S', 'S,жен,неод=вин,ед', 'OUT'],
#  [9, 'дело', 'дело', 'S', 'S,сред,неод=(вин,ед|им,ед)', 'OUT'],
#  [9, 'хотя', 'хотя', 'CONJ', 'CONJ=', 'OUT'],
#  [9, 'вами', 'вы', 'S-PRO', 'SPRO,мн,2-л=твор', 'OUT'],
#  [9, 'сказка', 'сказка', 'S', 'S,жен,неод=им,ед', 'OUT'],
#  [9, 'сказка', 'сказка', 'S', 'S,жен,неод=им,ед', 'OUT'],
#  [9, 'эта', 'этот', 'A-PRO=f', 'APRO=им,ед,жен', 'OUT'],
#  [9, 'очень', 'очень', 'ADV', 'ADV=', 'OUT'],
#  [9, 'очень', 'очень', 'ADV', 'ADV=', 'OUT'],
#  [9, 'простая', 'простой', 'A=f', 'A=им,ед,полн,жен', 'OUT'],
#  [10,
#   'начнем',
#   'начинать',
#   'A=n',
#   'V,пе=(мн,пов,1-л,сов|непрош,мн,изъяв,1-л,сов)',
#   'OUT'],
#  [10, 'начала', 'начало', 'V', 'S,сред,неод=(вин,мн|род,ед|им,мн)', 'OUT'],
#  [10, 'советует', 'советовать', 'V', 'V,несов,нп=непрош,ед,изъяв,3-л', 'OUT'],
#  [10,
#   'червонный',
#   'червонный',
#   'A=m',
#   'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)',
#   'OUT'],
#  [10, 'король', 'король', 'S', 'S,муж,од=им,ед', 'OUT'],
#  [10, 'предстоит', 'предстоять', 'V', 'V,несов,нп=непрош,ед,изъяв,3-л', 'OUT'],
#  [10, 'скоро', 'скоро', 'ADV', 'ADV=', 'OUT'],
#  [10, 'встретиться', 'встречаться', 'V', 'V,нп=инф,сов', 'OUT'],
#  [11, 'немножко', 'немножко', 'ADV', 'ADV=', 'OUT'],
#  [11, 'раньше', 'рано', 'ADV=comp', 'ADV=срав', 'OUT'],
#  [11, 'названия', 'название', 'S', 'S,сред,неод=(вин,мн|род,ед|им,мн)', 'OUT'],
#  [12,
#   'приключения',
#   'приключение',
#   'S',
#   'S,сред,неод=(вин,мн|род,ед|им,мн)',
#   'OUT'],
#  [12, 'алисы', 'алиса', 'S', 'S,имя,жен,од=(род,ед|им,мн)', 'OUT'],
#  [12, 'стране', 'страна', 'S', 'S,жен,неод=(пр,ед|дат,ед)', 'OUT'],
#  [12, 'чудес', 'чудо', 'S', 'S,сред,неод=род,мн', 'OUT'],
#  [13, 'будь', 'быть', 'V', 'V,нп=ед,пов,2-л', 'OUT'],
#  [13, 'воля', 'воля', 'S', 'S,жен,неод=им,ед', 'OUT'],
#  [13, 'назвал', 'называть', 'V', 'V,пе=прош,ед,изъяв,муж,сов', 'OUT'],
#  [13, 'книжку', 'книжка', 'S', 'S,жен,неод=вин,ед', 'OUT'],
#  [14, 'такое', 'такой', 'A-PRO=n', 'APRO=(вин,ед,сред|им,ед,сред)', 'OUT'],
#  [14, 'название', 'название', 'S', 'S,сред,неод=(вин,ед|им,ед)', 'OUT'],
#  [14, 'по-моему', 'по-моему', 'ADV-PRO', 'ADV,вводн=', 'OUT'],
#  [14, 'сбивает', 'сбивать', 'V', 'V,пе=непрош,ед,изъяв,3-л,несов', 'OUT'],
#  [14, 'толку', 'толк', 'S', 'S,муж,неод=(дат,ед|парт,ед)', 'OUT'],
#  [15, 'самом', 'самый', 'A-PRO=m', 'APRO=(пр,ед,муж|пр,ед,сред)', 'OUT'],
#  [15, 'деле', 'дело', 'S', 'S,сред,неод=пр,ед', 'OUT'],
#  [15, 'названию', 'название', 'S', 'S,сред,неод=дат,ед', 'OUT'],
#  [15,
#   'догадаешься',
#   'догадываться',
#   'V',
#   'V,нп=непрош,ед,изъяв,2-л,сов',
#   'OUT'],
#  [15, 'речь', 'речь', 'S', 'S,жен,неод=(вин,ед|им,ед)', 'OUT'],
#  [15, 'пойдет', 'пойти', 'V', 'V,сов,нп=непрош,ед,изъяв,3-л', 'OUT'],
#  [15,
#   'маленькой',
#   'маленький',
#   'A=f',
#   'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)',
#   'OUT'],
#  [15, 'хотя', 'хотя', 'CONJ', 'CONJ=', 'OUT'],
#  [15, 'очень', 'очень', 'ADV', 'ADV=', 'OUT'],
#  [15,
#   'умной',
#   'умный',
#   'A=f',
#   'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)',
#   'OUT'],
#  [15, 'девочке', 'девочка', 'S', 'S,жен,од=(пр,ед|дат,ед)', 'OUT'],
#  [15,
#   'приключения',
#   'приключение',
#   'S',
#   'S,сред,неод=(вин,мн|род,ед|им,мн)',
#   'OUT'],
#  [15, 'будут', 'быть', 'V', 'V,нп=непрош,мн,изъяв,3-л', 'OUT'],
#  [15, 'такие', 'такой', 'A-PRO=pl', 'APRO=(им,мн|вин,мн,неод)', 'OUT'],
#  [15, 'обычно', 'обычно', 'ADV', 'ADV=', 'OUT'],
#  [15, 'шпионов', 'шпион', 'S', 'S,муж,од=(вин,мн|род,мн)', 'OUT'],
#  [15, 'индейцев', 'индеец', 'S', 'S,муж,од=(вин,мн|род,мн)', 'OUT'],
#  [15, 'пиратов', 'пират', 'S', 'S,муж,од=(вин,мн|род,мн)', 'OUT'],
#  [15, 'сражений', 'сражение', 'S', 'S,сред,неод=род,мн', 'OUT'],
#  [15, 'землетрясений', 'землетрясение', 'A=m', 'S,сред,неод=род,мн', 'OUT'],
#  [15, 'кораблекрушений', 'кораблекрушение', 'S', 'S,сред,неод=род,мн', 'OUT'],
#  [15, 'охоты', 'охота', 'S', 'S,жен,неод=(вин,мн|род,ед|им,мн)', 'OUT'],
#  [15, 'крупную', 'крупный', 'A=f', 'A=вин,ед,полн,жен', 'OUT'],
#  [15, 'дичь', 'дичь', 'V', 'S,жен,неод=(вин,ед|им,ед)', 'OUT'],
#  [16, 'страна', 'страна', 'S', 'S,жен,неод=им,ед', 'OUT'],
#  [16, 'чудес', 'чудо', 'S', 'S,сред,неод=род,мн', 'OUT'],
#  [16, 'те', 'тот', 'A-PRO=pl', 'APRO=(им,мн|вин,мн,неод)', 'OUT'],
#  [16, 'слова', 'слово', 'S', 'S,сред,неод=(вин,мн|род,ед|им,мн)', 'OUT'],
#  [16, 'какие', 'какой', 'A-PRO=pl', 'APRO=(им,мн|вин,мн,неод)', 'OUT'],
#  [16, 'хотелось', 'хотеться', 'V', 'V,несов,нп=прош,ед,изъяв,сред', 'OUT'],
#  [16, 'написать', 'написать', 'V', 'V,сов,пе=инф', 'OUT'],
#  [16, 'заглавии', 'заглавие', 'S', 'S,сред,неод=пр,ед', 'OUT'],
#  [16, 'сказки', 'сказка', 'S', 'S,жен,неод=(вин,мн|род,ед|им,мн)', 'OUT'],
#  [17, 'будь', 'быть', 'V', 'V,нп=ед,пов,2-л', 'OUT'],
#  [17, 'воля', 'воля', 'S', 'S,жен,неод=им,ед', 'OUT'],
#  [17, 'назвал', 'называть', 'V', 'V,пе=прош,ед,изъяв,муж,сов', 'OUT'],
#  [17, 'книжку', 'книжка', 'S', 'S,жен,неод=вин,ед', 'OUT'],
#  [17, 'например', 'например', 'PARENTH', 'ADV,вводн=', 'OUT'],
#  [17, 'аленка', 'аленка', 'S', 'S,имя,жен,од=им,ед', 'OUT'],
#  [17,
#   'вообразилии',
#   'вообразилия',
#   'ADV',
#   'S,гео,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)',
#   'OUT'],
#  [18, 'аля', 'аля', 'S', 'S,имя,жен,од=им,ед', 'OUT'],
#  [18,
#   'удивляндии',
#   'удивляндия',
#   'S',
#   'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)',
#   'OUT'],
#  [19, 'алька', 'алька', 'S', 'S,имя,муж,од=им,ед', 'OUT'],
#  [19, 'чепухании', 'чепухание', 'S', 'S,сред,неод=пр,ед', 'OUT'],
#  [20,
#   'худой',
#   'худой',
#   'A=m',
#   'A=(вин,ед,полн,муж,неод|им,ед,полн,муж|пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)',
#   'OUT'],
#  [20, 'конец', 'конец', 'S', 'S,муж,неод=(вин,ед|им,ед)', 'OUT'],
#  [20, 'алиска', 'алиска', 'S', 'S,имя,жен,од=им,ед', 'OUT'],
#  [20, 'расчудесии', 'расчудесий', 'S', 'S,имя,муж,од=(пр,ед|им,мн)', 'OUT'],
#  [21, 'стоило', 'стоить', 'V', 'V,несов=прош,ед,изъяв,сред', 'OUT'],
#  [21, 'заикнуться', 'заикаться', 'V', 'V,нп=инф,сов', 'OUT'],
#  [21, 'своем', 'свой', 'V', 'APRO=(пр,ед,муж|пр,ед,сред)', 'OUT'],
#  [21, 'желании', 'желание', 'S', 'S,сред,неод=пр,ед', 'OUT'],
#  [21, 'начинали', 'начинать', 'V', 'V,пе=прош,мн,изъяв,несов', 'OUT'],
#  [21, 'страшно', 'страшно', 'PRAEDIC', 'ADV=', 'OUT'],
#  [21, 'кричать', 'кричать', 'V', 'V,несов,нп=инф', 'OUT'],
#  [21, 'смел', 'сметь', 'V', 'V,несов,нп=прош,ед,изъяв,муж', 'OUT'],
#  [22, 'посмел', 'посметь', 'V', 'V,сов,нп=прош,ед,изъяв,муж', 'OUT'],
#  [23, 'горе', 'горе', 'S', 'S,ед,сред,неод=(пр|вин|им)', 'OUT'],
#  [23, 'книжка', 'книжка', 'S', 'S,жен,неод=им,ед', 'OUT'],
#  [23, 'эта', 'этот', 'A-PRO=f', 'APRO=им,ед,жен', 'OUT'],
#  [23,
#   'написана',
#   'написать',
#   'V',
#   'V,сов,пе=прош,ед,прич,кр,жен,страд',
#   'OUT'],
#  [23,
#   'англии',
#   'англия',
#   'S',
#   'S,гео,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)',
#   'OUT'],
#  [23, 'сто', 'сто', 'ADV', 'NUM=(вин|им)', 'OUT'],
#  [23, 'лет', 'год', 'S', 'S,муж,неод=род,мн', 'OUT'],
#  [23, 'тому', 'то', 'A-PRO=m', 'SPRO,ед,сред,неод=дат', 'OUT'],
#  [23, 'назад', 'назад', 'ADV', 'ADV=', 'OUT'],
#  [23, 'это', 'этот', 'S-PRO', 'APRO=(вин,ед,сред|им,ед,сред)', 'OUT'],
#  [23, 'время', 'время', 'S', 'S,сред,неод=(вин,ед|им,ед)', 'OUT'],
#  [23, 'успела', 'успевать', 'V', 'V,нп=прош,ед,изъяв,жен,сов', 'OUT'],
#  [23, 'прославиться', 'прославляться', 'V', 'V,нп=инф,сов', 'OUT'],
#  [23, 'хотя', 'хотя', 'CONJ', 'PART=', 'OUT'],
#  [23, 'понаслышке', 'понаслышке', 'ADV', 'ADV=', 'OUT'],
#  [23, 'знают', 'знать', 'V', 'V,несов,пе=непрош,мн,изъяв,3-л', 'OUT'],
#  [23, 'алису', 'алиса', 'S', 'S,имя,жен,од=вин,ед', 'OUT'],
#  [23, 'привыкли', 'привыкать', 'V', 'V,нп=прош,мн,изъяв,сов', 'OUT'],
#  [23,
#   'скучноватому',
#   'скучноватый',
#   'A-PRO=m',
#   'A=(дат,ед,полн,муж|дат,ед,полн,сред)',
#   'OUT'],
#  [23, 'названию', 'название', 'S', 'S,сред,неод=дат,ед', 'OUT'],
#  [23,
#   'приключения',
#   'приключение',
#   'S',
#   'S,сред,неод=(вин,мн|род,ед|им,мн)',
#   'OUT'],
#  [23, 'алисы', 'алиса', 'S', 'S,имя,жен,од=(род,ед|им,мн)', 'OUT'],
#  [23, 'стране', 'страна', 'S', 'S,жен,неод=(пр,ед|дат,ед)', 'OUT'],
#  [23, 'чудес', 'чудо', 'S', 'S,сред,неод=род,мн', 'OUT'],
#  [24, 'это', 'это', 'S-PRO', 'SPRO,ед,сред,неод=(вин|им)', 'OUT'],
#  [24,
#   'называется',
#   'называться',
#   'V',
#   'V,несов,нп=непрош,ед,изъяв,3-л',
#   'OUT'],
#  [24,
#   'литературной',
#   'литературный',
#   'A=f',
#   'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)',
#   'OUT'],
#  [24, 'традицией', 'традиция', 'S', 'S,жен,неод=твор,ед', 'OUT'],
#  [24, 'говорится', 'говориться', 'V', 'V,несов,нп=непрош,ед,изъяв,3-л', 'OUT'],
#  [24, 'попишешь', 'пописать', 'V', 'V,сов,пе=непрош,ед,изъяв,2-л', 'OUT'],
#  [25, 'хотя', 'хотя', 'CONJ', 'CONJ=', 'OUT'],
#  [25, 'название', 'название', 'S', 'S,сред,неод=(вин,ед|им,ед)', 'OUT'],
#  [25, 'алиска', 'алиска', 'S', 'S,имя,жен,од=им,ед', 'OUT'],
#  [25, 'расчудесии', 'расчудесий', 'S', 'S,имя,муж,од=(пр,ед|им,мн)', 'OUT'],
#  [25, 'гораздо', 'гораздо', 'ADV', 'ADV=', 'OUT'],
#  [25, 'похоже', 'похожий', 'A=comp2', 'A=ед,кр,сред', 'OUT'],
#  [25,
#   'настоящее',
#   'настоящий',
#   'A=n',
#   'A=(вин,ед,полн,сред|им,ед,полн,сред|срав)',
#   'OUT'],
#  [25,
#   'английское',
#   'английский',
#   'A=n',
#   'A=(вин,ед,полн,сред|им,ед,полн,сред)',
#   'OUT'],
#  [25, 'название', 'название', 'S', 'S,сред,неод=(вин,ед|им,ед)', 'OUT'],
#  [25, 'сказки', 'сказка', 'S', 'S,жен,неод=(вин,мн|род,ед|им,мн)', 'OUT'],
#  [25, 'назвал', 'называть', 'V', 'V,пе=прош,ед,изъяв,муж,сов', 'OUT'],
#  [25, 'люди', 'человек', 'S', 'S,муж,од=им,мн', 'OUT'],
#  [25, 'подумали', 'подумать', 'V', 'V,сов,нп=прош,мн,изъяв', 'OUT'],
#  [25, 'это', 'это', 'S-PRO', 'SPRO,ед,сред,неод=(вин|им)', 'OUT'],
#  [25, 'совершенно', 'совершенно', 'ADV', 'ADV=', 'OUT'],
#  [25, 'другая', 'другой', 'A-PRO=f', 'APRO=им,ед,жен', 'OUT'],
#  [25, 'книжка', 'книжка', 'S', 'S,жен,неод=им,ед', 'OUT'],
#  [25, 'та', 'тот', 'A-PRO=f', 'APRO=им,ед,жен', 'OUT'],
#  [25, 'знаменитая', 'знаменитый', 'A=f', 'A=им,ед,полн,жен', 'OUT'],
#  [26, 'знаменита', 'знаменитый', 'V', 'A=ед,кр,жен', 'OUT'],
#  [26, 'алиса', 'алиса', 'S', 'S,имя,жен,од=им,ед', 'OUT'],
#  [26, 'действительно', 'действительно', 'ADV', 'ADV,вводн=', 'OUT'],
#  [26, 'сверх', 'сверх', 'PR', 'PR=', 'OUT'],
#  [26,
#   'всякой',
#   'всякий',
#   'A-PRO=f',
#   'APRO=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)',
#   'OUT'],
#  [26, 'меры', 'мера', 'S', 'S,жен,неод=(вин,мн|род,ед|им,мн)', 'OUT'],
#  [27,
#   'особенности',
#   'особенность',
#   'S',
#   'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)',
#   'OUT'],
#  [27, 'тех', 'тот', 'A-PRO=pl', 'APRO=(пр,мн|род,мн|вин,мн,од)', 'OUT'],
#  [27, 'странах', 'страна', 'S', 'S,жен,неод=пр,мн', 'OUT'],
#  [27, 'говорят', 'говорить', 'V', 'V,несов,пе=непрош,мн,изъяв,3-л', 'OUT'],
#  [27, 'по-английски', 'по-английски', 'ADV', 'ADV=', 'OUT'],
#  [28, 'знает', 'знать', 'V', 'V,несов,пе=непрош,ед,изъяв,3-л', 'OUT'],
#  [28,
#   'каждый',
#   'каждый',
#   'A-PRO=m',
#   'APRO=(вин,ед,муж,неод|им,ед,муж)',
#   'OUT'],
#  [28, 'любят', 'любить', 'V', 'V,несов,пе=непрош,мн,изъяв,3-л', 'OUT'],
#  [29, 'самое', 'самый', 'A-PRO=n', 'APRO=(вин,ед,сред|им,ед,сред)', 'OUT'],
#  [29,
#   'интересное',
#   'интересный',
#   'A=n',
#   'A=(вин,ед,полн,сред|им,ед,полн,сред)',
#   'OUT'],
#  [29, 'хотя', 'хотя', 'CONJ', 'CONJ=', 'OUT'],
#  [29, 'эта', 'этот', 'A-PRO=f', 'APRO=им,ед,жен', 'OUT'],
#  [29, 'сказка', 'сказка', 'S', 'S,жен,неод=им,ед', 'OUT'],
#  [29, 'детей', 'ребенок', 'S', 'S,муж,од=(вин,мн|род,мн)', 'OUT'],
#  [29, 'пожалуй', 'пожалуй', 'PARENTH', 'PART,вводн=', 'OUT'],
#  [29, 'детей', 'ребенок', 'S', 'S,муж,од=(вин,мн|род,мн)', 'OUT'],
#  [29, 'любят', 'любить', 'V', 'V,несов,пе=непрош,мн,изъяв,3-л', 'OUT'],
#  [29, 'взрослые', 'взрослый', 'A=pl', 'S,муж,од=им,мн', 'OUT'],
#  [29, 'самые', 'самый', 'A-PRO=pl', 'APRO=(им,мн|вин,мн,неод)', 'OUT'],
#  [29, 'взрослые', 'взрослый', 'A=pl', 'S,муж,од=им,мн', 'OUT'],
#  [29, 'взрослых', 'взрослый', 'A=pl', 'S,муж,од=(пр,мн|вин,мн|род,мн)', 'OUT'],
#  [29, 'ученые', 'ученый', 'A=pl', 'S,муж,од=им,мн', 'OUT'],
#  [30, 'сразу', 'сразу', 'ADV', 'ADV=', 'OUT'],
#  [30, 'видно', 'видно', 'PRAEDIC', 'ADV,прдк=', 'OUT'],
#  [30, 'это', 'это', 'S-PRO', 'SPRO,ед,сред,неод=(вин|им)', 'OUT'],
#  [30, 'очень', 'очень', 'ADV', 'ADV=', 'OUT'],
#  [30, 'очень', 'очень', 'ADV', 'ADV=', 'OUT'],
#  [30, 'непростая', 'непростой', 'A=f', 'A=им,ед,полн,жен', 'OUT'],
#  [30, 'сказка', 'сказка', 'S', 'S,жен,неод=им,ед', 'OUT'],
#  [31, 'мало', 'мало', 'ADV', 'ADV=', 'OUT'],
#  [32, 'написаны', 'написать', 'V', 'V,сов,пе=прош,мн,прич,кр,страд', 'OUT'],
#  [32, 'целые', 'целый', 'A=pl', 'A=(вин,мн,полн,неод|им,мн,полн)', 'OUT'],
#  [32, 'горы', 'гора', 'S', 'S,жен,неод=(вин,мн|род,ед|им,мн)', 'OUT'],
#  [32, 'книг', 'книга', 'S', 'S,жен,неод=род,мн', 'OUT'],
#  [32,
#   'которых',
#   'который',
#   'A-PRO=pl',
#   'APRO=(пр,мн|род,мн|вин,мн,од)',
#   'OUT'],
#  [32, 'алису', 'алиса', 'S', 'S,имя,жен,од=вин,ед', 'OUT'],
#  [32, 'лады', 'лад', 'S', 'S,муж,неод=(вин,мн|им,мн)', 'OUT'],
#  [32,
#   'растолковывают',
#   'растолковывать',
#   'V',
#   'V=непрош,мн,изъяв,3-л,несов,пе',
#   'OUT'],
#  [32, 'объясняют', 'объяснять', 'V', 'V,пе=непрош,мн,изъяв,3-л,несов', 'OUT'],
#  [33, 'долго', 'долго', 'ADV', 'ADV=', 'OUT'],
#  [33, 'объясняют', 'объяснять', 'V', 'V,пе=непрош,мн,изъяв,3-л,несов', 'OUT'],
#  [33, 'это', 'это', 'S-PRO', 'SPRO,ед,сред,неод=(вин|им)', 'OUT'],
#  [33, 'по-моему', 'по-моему', 'ADV-PRO', 'ADV,вводн=', 'OUT'],
#  [33, 'значит', 'значит', 'V', 'ADV,вводн=', 'OUT'],
#  [33, 'люди', 'человек', 'S', 'S,муж,од=им,мн', 'OUT'],
#  [33, 'сами', 'сам', 'A-PRO=pl', 'APRO=(им,мн|вин,мн,неод)', 'OUT'],
#  [33, 'поняли', 'понимать', 'V', 'V=прош,мн,изъяв,сов', 'OUT'],
#  [34, 'очень', 'очень', 'ADV', 'ADV=', 'OUT'],
#  [34, 'огорчайтесь', 'огорчаться', 'V', 'V,нп=мн,пов,2-л,несов', 'OUT'],
#  [34, 'сразу', 'сразу', 'ADV', 'ADV=', 'OUT'],
#  [34, 'поймете', 'понимать', 'V', 'V=непрош,мн,изъяв,2-л,сов', 'OUT'],
#  [35, 'перечитать', 'перечитывать', 'V', 'V=инф,сов', 'OUT'],
#  [35,
#   'непонятное',
#   'непонятный',
#   'A=n',
#   'A=(вин,ед,полн,сред|им,ед,полн,сред)',
#   'OUT'],
#  [35, 'место', 'место', 'S', 'S,сред,неод=(вин,ед|им,ед)', 'OUT'],
#  [35, 'разок', 'разок', 'S', 'S,муж,неод=(вин,ед|им,ед)', 'OUT'],
#  [35, 'правда', 'правда', 'PARENTH', 'ADV,вводн=', 'OUT'],
#  [35, 'надеюсь', 'надеяться', 'V', 'V,несов,нп=непрош,ед,изъяв,1-л', 'OUT'],
#  [35, 'слишком', 'слишком', 'ADV', 'ADV=', 'OUT'],
#  [35, 'запугал', 'запугивать', 'V', 'V,пе=прош,ед,изъяв,муж,сов', 'OUT'],
#  [36,
#   'совести',
#   'совесть',
#   'S',
#   'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)',
#   'OUT'],
#  [36, 'говоря', 'говорить', 'V', 'V,несов,пе=непрош,деепр', 'OUT'],
#  [36, 'бояться', 'бояться', 'V', 'V,несов,нп=инф', 'OUT'],
#  [36, 'нечего', 'нечего', 'PRAEDIC-PRO', 'ADV,прдк=', 'OUT'],
#  [37, 'правильно', 'правильно', 'ADV', 'ADV=', 'OUT'],
#  [37, 'прочитать', 'прочитывать', 'V', 'V=инф,сов', 'OUT'],
#  [37, 'понять', 'понимать', 'V', 'V=инф,сов', 'OUT'],
#  [37, 'сказку', 'сказка', 'S', 'S,жен,неод=вин,ед', 'OUT'],
#  [37, 'нужны', 'нужный', 'A=pl', 'A=мн,кр', 'OUT'],
#  [37, 'две', 'два', 'NUM=f', 'NUM=(им,жен|вин,жен,неод)', 'OUT'],
#  [37,
#   'вещи',
#   'вещь',
#   'S',
#   'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)',
#   'OUT'],
#  [38, 'нужно', 'нужно', 'PRAEDIC', 'ADV,прдк=', 'OUT'],
#  [38, 'это', 'это', 'S-PRO', 'SPRO,ед,сред,неод=(вин|им)', 'OUT'],
#  [38, 'совершенно', 'совершенно', 'ADV', 'ADV=', 'OUT'],
#  [38, 'обязательно', 'обязательный', 'ADV', 'A=ед,кр,сред', 'OUT'],
#  [39, 'иметь', 'иметь', 'V', 'V,несов,пе=инф', 'OUT'],
#  [39, 'чувство', 'чувство', 'S', 'S,сред,неод=(вин,ед|им,ед)', 'OUT'],
#  [39, 'юмора', 'юмор', 'S', 'S,муж,неод=род,ед', 'OUT'],
#  [39, 'это', 'это', 'S-PRO', 'PART=', 'OUT'],
#  [39, 'одна', 'один', 'A-PRO=f', 'APRO=им,ед,жен', 'OUT'],
#  [39, 'самых', 'самый', 'A-PRO=pl', 'APRO=(пр,мн|род,мн|вин,мн,од)', 'OUT'],
#  [39,
#   'веселых',
#   'веселый',
#   'A=pl',
#   'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)',
#   'OUT'],
#  [39, 'книжек', 'книжка', 'S', 'S,жен,неод=род,мн', 'OUT'],
#  [39, 'свете', 'свет', 'S', 'S,ед,муж,неод=пр', 'OUT'],
#  [40, 'совершенно', 'совершенно', 'ADV', 'ADV=', 'OUT'],
#  [40, 'спокоен', 'спокойный', 'V', 'A=ед,кр,муж', 'OUT'],
#  [40, 'уверен', 'уверенный', 'A=m', 'A=ед,кр,муж', 'OUT'],
#  [40, 'смеяться', 'смеяться', 'V', 'V,несов,нп=инф', 'OUT'],
#  [40, 'умеете', 'уметь', 'V', 'V,несов,нп=непрош,мн,изъяв,2-л', 'OUT'],
#  [40,
#   'любите',
#   'любить',
#   'V',
#   'V,несов,пе=(непрош,мн,изъяв,2-л|мн,пов,2-л)',
#   'OUT'],
#  [41, 'нужно', 'нужно', 'PRAEDIC', 'ADV,прдк=', 'OUT'],
#  [41, 'это', 'это', 'S-PRO', 'SPRO,ед,сред,неод=(вин|им)', 'OUT'],
#  [41, 'совершенно', 'совершенно', 'ADV', 'ADV=', 'OUT'],
#  [41, 'обязательно', 'обязательно', 'ADV', 'ADV=', 'OUT'],
#  [42, 'кое-что', 'кое-что', 'S-PRO', 'SPRO,ед,сред,неод=(вин|им)', 'OUT'],
#  [42, 'знать', 'знать', 'V', 'V,несов,пе=инф', 'OUT'],
#  [43, 'голове', 'голова', 'S', 'S,жен,неод=(пр,ед|дат,ед)', 'OUT'],
#  [43, 'пусто', 'пусто', 'ADV', 'ADV=', 'OUT'],
#  [43, 'увы', 'увы', 'INTJ', 'INTJ=', 'OUT'],
#  [43, 'самое', 'самый', 'A-PRO=n', 'APRO=(вин,ед,сред|им,ед,сред)', 'OUT'],
#  [43,
#   'большое',
#   'большой',
#   'A=n',
#   'A=(вин,ед,полн,сред|им,ед,полн,сред)',
#   'OUT'],
#  [43, 'чувство', 'чувство', 'S', 'S,сред,неод=(вин,ед|им,ед)', 'OUT'],
#  [43, 'юмора', 'юмор', 'S', 'S,муж,неод=род,ед', 'OUT'],
#  [43, 'спасет', 'спасать', 'V', 'V=непрош,ед,изъяв,3-л,сов', 'OUT'],
#  [44,
#   'маленький',
#   'маленький',
#   'A=m',
#   'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)',
#   'OUT'],
#  [44, 'пример', 'пример', 'S', 'S,муж,неод=(вин,ед|им,ед)', 'OUT'],
#  [45, 'знакомый', 'знакомый', 'A=m', 'S,муж,од=им,ед', 'OUT'],
#  [45, 'приблизительно', 'приблизительно', 'ADV', 'ADV=', 'OUT'],
#  [45, 'двух', 'два', 'NUM=f', 'NUM=(пр|род|вин,муж,од|вин,жен,од)', 'OUT'],
#  [45, 'лет', 'год', 'S', 'S,муж,неод=род,мн', 'OUT'],
#  [45, 'роду', 'род', 'S', 'S,муж,неод=(дат,ед|местн,ед)', 'OUT'],
#  [45,
#   'которого',
#   'который',
#   'A-PRO=m',
#   'APRO=(вин,ед,муж,од|род,ед,муж|род,ед,сред)',
#   'OUT'],
#  [45,
#   'огромное',
#   'огромный',
#   'A=n',
#   'A=(вин,ед,полн,сред|им,ед,полн,сред)',
#   'OUT'],
#  [45, 'чувство', 'чувство', 'S', 'S,сред,неод=(вин,ед|им,ед)', 'OUT'],
#  [45, 'юмора', 'юмор', 'S', 'S,муж,неод=род,ед', 'OUT'],
#  [45, 'захохотать', 'захохотать', 'V', 'V,сов,нп=инф', 'OUT'],
#  [45, 'никому', 'никто', 'S-PRO', 'SPRO,ед,муж,од=дат', 'OUT'],
#  [45, 'другому', 'другой', 'A-PRO=m', 'APRO=(дат,ед,муж|дат,ед,сред)', 'OUT'],
#  [45, 'голову', 'голова', 'S', 'S,жен,неод=вин,ед', 'OUT'],
#  [45, 'придет', 'прийти', 'V', 'V,сов,нп=непрош,ед,изъяв,3-л', 'OUT'],
#  [45, 'улыбнуться', 'улыбаться', 'V', 'V,нп=инф,сов', 'OUT'],
#  [46, 'любимая', 'любимый', 'A=f', 'A=им,ед,полн,жен', 'OUT'],
#  [46, 'шутка', 'шутка', 'S', 'S,жен,неод=им,ед', 'OUT'],
#  [46, 'придумал', 'придумывать', 'V', 'V,пе=прош,ед,изъяв,муж,сов', 'OUT'],
#  [46, 'такая', 'такой', 'A-PRO=f', 'APRO=им,ед,жен', 'OUT'],
#  [46, 'андрюшенька', 'андрюшенька', 'S', 'S,имя,муж,од=им,ед', 'OUT'],
#  [46, 'говорит', 'говорить', 'V', 'V,несов,пе=непрош,ед,изъяв,3-л', 'OUT'],
#  [46, 'курочка', 'курочка', 'S', 'S,жен,од=им,ед', 'OUT'],
#  [46,
#   'му',
#   'му',
#   'S',
#   'S,сред,неод=(пр,мн|пр,ед|вин,мн|вин,ед|дат,мн|дат,ед|род,мн|род,ед|твор,мн|твор,ед|им,мн|им,ед)',
#   'OUT'],
#  [47,
#   'му',
#   'му',
#   'S',
#   'S,сред,неод=(пр,мн|пр,ед|вин,мн|вин,ед|дат,мн|дат,ед|род,мн|род,ед|твор,мн|твор,ед|им,мн|им,ед)',
#   'OUT'],
#  [48,
#   'му',
#   'му',
#   'S',
#   'S,сред,неод=(пр,мн|пр,ед|вин,мн|вин,ед|дат,мн|дат,ед|род,мн|род,ед|твор,мн|твор,ед|им,мн|им,ед)',
#   'OUT'],
#  [49, 'андрюшенька', 'андрюшенька', 'S', 'S,имя,муж,од=им,ед', 'OUT'],
#  [49,
#   'заливается',
#   'заливаться',
#   'V',
#   'V,нп=непрош,ед,изъяв,3-л,несов',
#   'OUT'],
#  [49, 'смехом', 'смех', 'S', 'S,муж,неод=твор,ед', 'OUT'],
#  [50, 'скажете', 'сказать', 'V', 'V,сов,пе=непрош,мн,изъяв,2-л', 'OUT'],
#  [50, 'ихтиозавр', 'ихтиозавр', 'V', 'S,муж,од=им,ед', 'OUT'],
#  [50, 'говорит', 'говорить', 'V', 'V,несов,пе=непрош,ед,изъяв,3-л', 'OUT'],
#  [50, 'ах', 'ах', 'INTJ', 'INTJ=', 'OUT'],
#  [50, 'батюшки', 'батюшка', 'S', 'S,муж,од=(род,ед|им,мн)', 'OUT'],
#  [50, 'мои', 'мой', 'A-PRO=pl', 'APRO=(им,мн|вин,мн,неод)', 'OUT'],
#  [50, 'андрюшенька', 'андрюшенька', 'S', 'S,имя,муж,од=им,ед', 'OUT'],
#  [50, 'улыбнется', 'улыбаться', 'V', 'V,нп=непрош,ед,изъяв,3-л,сов', 'OUT'],
#  [51, 'дело', 'дело', 'S', 'S,сред,неод=(вин,ед|им,ед)', 'OUT'],
#  [51, 'очень', 'очень', 'ADV', 'ADV=', 'OUT'],
#  [51, 'плохо', 'плохо', 'ADV', 'ADV=', 'OUT'],
#  [51, 'знаком', 'знакомый', 'A=m', 'A=ед,кр,муж', 'OUT'],
#  [51, 'повадками', 'повадка', 'S', 'S,жен,неод=твор,мн', 'OUT'],
#  [51, 'ихтиозавров', 'ихтиозавр', 'S', 'S,муж,од=(вин,мн|род,мн)', 'OUT'],
#  [52, 'читать', 'читать', 'V', 'V,несов,пе=инф', 'OUT'],
#  [52, 'книжку', 'книжка', 'S', 'S,жен,неод=вин,ед', 'OUT'],
#  [52, 'по-настоящему', 'по-настоящему', 'ADV', 'ADV=', 'OUT'],
#  [52, 'читать', 'читать', 'V', 'V,несов,пе=инф', 'OUT'],
#  [52, 'по-настоящему', 'по-настоящему', 'ADV', 'ADV=', 'OUT'],
#  [52, 'это', 'это', 'S-PRO', 'SPRO,ед,сред,неод=(вин|им)', 'OUT'],
#  [52, 'значит', 'значить', 'V', 'V,несов,пе=непрош,ед,изъяв,3-л', 'OUT'],
#  [52, 'читать', 'читать', 'V', 'V,несов,пе=инф', 'OUT'],
#  [52, 'смеяться', 'смеяться', 'V', 'V,несов,нп=инф', 'OUT'],
#  [53, 'знать', 'знать', 'V', 'V,несов,пе=инф', 'OUT'],
#  [53,
#   'многое',
#   'многий',
#   'S-PRO',
#   'APRO=(вин,ед,полн,сред|им,ед,полн,сред)',
#   'OUT'],
#  [53, 'множество', 'множество', 'S', 'S,сред,неод=(вин,ед|им,ед)', 'OUT'],
#  [53, 'самых', 'самый', 'A-PRO=pl', 'APRO=(пр,мн|род,мн|вин,мн,од)', 'OUT'],
#  [53,
#   'разных',
#   'разный',
#   'A=pl',
#   'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)',
#   'OUT'],
#  [53, 'разностей', 'разность', 'S', 'S,жен,неод=род,мн', 'OUT'],
#  [54, 'знать', 'знать', 'V', 'V,несов,пе=инф', 'OUT'],
#  [54, 'такие', 'такой', 'A-PRO=pl', 'APRO=(им,мн|вин,мн,неод)', 'OUT'],
#  [54, 'антиподы', 'антипод', 'S', 'S,муж,од=им,мн', 'OUT'],
#  [54, 'такое', 'такой', 'A-PRO=n', 'APRO=(вин,ед,сред|им,ед,сред)', 'OUT'],
#  [54,
#   'параллели',
#   'параллель',
#   'V',
#   'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)',
#   'OUT'],
#  [54, 'меридианы', 'меридиан', 'V', 'S,муж,неод=(вин,мн|им,мн)', 'OUT'],
#  [54, 'знать', 'знать', 'V', 'V,несов,пе=инф', 'OUT'],
#  [54, 'случилось', 'случаться', 'V', 'V,нп=прош,ед,изъяв,сред,сов', 'OUT'],
#  [54, 'такое', 'такой', 'A-PRO=n', 'APRO=(вин,ед,сред|им,ед,сред)', 'OUT'],
#  [54, 'ткань', 'ткань', 'V', 'S,жен,неод=(вин,ед|им,ед)', 'OUT'],
#  [54,
#   'повествования',
#   'повествование',
#   'S',
#   'S,сред,неод=(вин,мн|род,ед|им,мн)',
#   'OUT'],
#  [54, 'знать', 'знать', 'V', 'V,несов,пе=инф', 'OUT'],
#  [54, 'делается', 'делаться', 'V', 'V,несов,нп=непрош,ед,изъяв,3-л', 'OUT'],
#  [54, 'горчица', 'горчица', 'S', 'S,жен,неод=им,ед', 'OUT'],
#  [54, 'правильно', 'правильно', 'ADV', 'ADV=', 'OUT'],
#  [54, 'играть', 'играть', 'V', 'V,несов,пе=инф', 'OUT'],
#  [54, 'крокет', 'крокет', 'S', 'S,муж,неод=(вин,ед|им,ед)', 'OUT'],
#  [54, 'такие', 'такой', 'A-PRO=pl', 'APRO=(им,мн|вин,мн,неод)', 'OUT'],
#  [54, 'присяжные', 'присяжный', 'A=pl', 'S,муж,од=им,мн', 'OUT'],
#  [54,
#   'отличаются',
#   'отличаться',
#   'V',
#   'V,нп=непрош,мн,изъяв,3-л,несов',
#   'OUT'],
#  [54,
#   'пристяжных',
#   'пристяжной',
#   'A=pl',
#   'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)',
#   'OUT'],
#  [54,
#   'какого',
#   'какой',
#   'A-PRO=m',
#   'APRO=(вин,ед,муж,од|род,ед,муж|род,ед,сред)',
#   'OUT'],
#  [54, 'рода', 'род', 'S', 'S,муж,неод=(вин,мн|род,ед|им,мн)', 'OUT'],
#  [54, 'время', 'время', 'S', 'S,сред,неод=(вин,ед|им,ед)', 'OUT'],
#  [54, 'курят', 'курить', 'V', 'V,несов,пе=непрош,мн,изъяв,3-л', 'OUT'],
#  [54, 'червяки', 'червяк', 'S', 'S,муж,од=им,мн', 'OUT'],
#  [54, 'кальян', 'кальян', 'S', 'S,муж,неод=(вин,ед|им,ед)', 'OUT'],
#  [54, 'носят', 'носить', 'V', 'V,несов,пе=непрош,мн,изъяв,3-л', 'OUT'],
#  [54, 'лягушки', 'лягушка', 'S', 'S,жен,од=(род,ед|им,мн)', 'OUT'],
#  [54, 'караси', 'карась', 'S', 'S,муж,од=им,мн', 'OUT'],
#  [54, 'судьи', 'судья', 'S', 'S,мж,од=(род,ед|им,мн)', 'OUT'],
#  [54, 'парики', 'парик', 'S', 'S,муж,неод=(вин,мн|им,мн)', 'OUT'],
#  [54, 'питаться', 'питаться', 'V', 'V,несов,нп=инф', 'OUT'],
#  [54,
#   'одним',
#   'один',
#   'ANUM=m',
#   'APRO=(дат,мн|твор,ед,муж|твор,ед,сред)',
#   'OUT'],
#  [54, 'мармеладом', 'мармелад', 'S', 'S,муж,неод=твор,ед', 'OUT'],
#  [55, 'далее', 'далее', 'ADV', 'ADV=', 'OUT'],
#  [55, 'тому', 'то', 'A-PRO=m', 'SPRO,ед,сред,неод=дат', 'OUT'],
#  [55,
#   'подобное',
#   'подобный',
#   'A=n',
#   'A=(вин,ед,полн,сред|им,ед,полн,сред)',
#   'OUT'],
#  [56, 'кстати', 'кстати', 'PARENTH', 'ADV,вводн=', 'OUT'],
#  [56, 'случайно', 'случайно', 'ADV', 'ADV,вводн=', 'OUT'],
#  [56, 'упомянул', 'упоминать', 'V', 'V,пе=прош,ед,изъяв,муж,сов', 'OUT'],
#  [56, 'ихтиозавров', 'ихтиозавр', 'S', 'S,муж,од=(вин,мн|род,мн)', 'OUT'],
#  [56,
#   'ископаемые',
#   'ископаемый',
#   'A=pl',
#   'A=(вин,мн,полн,неод|им,мн,полн)',
#   'OUT'],
#  [56,
#   'всевозможные',
#   'всевозможный',
#   'A=pl',
#   'A=(вин,мн,полн,неод|им,мн,полн)',
#   'OUT'],
#  [56, 'ископаемые', 'ископаемое', 'A=pl', 'S,сред,неод=(вин,мн|им,мн)', 'OUT'],
#  [56, 'сказке', 'сказка', 'S', 'S,жен,неод=(пр,ед|дат,ед)', 'OUT'],
#  [56,
#   'встречаются',
#   'встречаться',
#   'V',
#   'V,нп=непрош,мн,изъяв,3-л,несов',
#   'OUT'],
#  [56, 'каждом', 'каждый', 'A-PRO=m', 'APRO=(пр,ед,муж|пр,ед,сред)', 'OUT'],
#  [56, 'шагу', 'шаг', 'S', 'S,муж,неод=(дат,ед|парт,ед|местн,ед)', 'OUT'],
#  [56, 'например', 'например', 'PARENTH', 'ADV,вводн=', 'OUT'],
#  [57, 'короли', 'король', 'S', 'S,муж,од=им,мн', 'OUT'],
#  [57, 'герцогини', 'герцогиня', 'V', 'S,жен,од=(род,ед|им,мн)', 'OUT'],
#  [57, 'графы', 'граф', 'S', 'S,муж,од=им,мн', 'OUT'],
#  [57, 'эрлы', 'эрл', 'S', 'S,муж,од=им,мн', 'OUT'],
#  [57,
#   'сущности',
#   'сущность',
#   'S',
#   'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)',
#   'OUT'],
#  [57, 'это', 'это', 'S-PRO', 'PART=', 'OUT'],
#  [57, 'одно', 'один', 'A-PRO=n', 'APRO=(вин,ед,сред|им,ед,сред)', 'OUT'],
#  [58, 'лакеи', 'лакей', 'S', 'S,муж,од=им,мн', 'OUT'],
#  [58,
#   'вымершая',
#   'вымирать',
#   'V',
#   'V,нп=прош,им,ед,прич,полн,жен,сов,действ',
#   'OUT'],
#  [58, 'птица', 'птица', 'S', 'S,жен,од=им,ед', 'OUT'],
#  [58,
#   'додо',
#   'додо',
#   'ADV',
#   'S,муж,од=(пр,мн|пр,ед|вин,мн|вин,ед|дат,мн|дат,ед|род,мн|род,ед|твор,мн|твор,ед|им,мн|им,ед)',
#   'OUT'],
#  [58,
#   'ископаемый',
#   'ископаемый',
#   'V',
#   'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)',
#   'OUT'],
#  [58, 'дронт', 'дронт', 'S', 'S,муж,од=им,ед', 'OUT'],
#  [59, 'это', 'это', 'S-PRO', 'SPRO,ед,сред,неод=(вин|им)', 'OUT'],
#  [59, 'удивительно', 'удивительно', 'PRAEDIC', 'ADV=', 'OUT'],
#  [59, 'забыли', 'забывать', 'V', 'V=прош,мн,изъяв,сов', 'OUT'],
#  [59, 'сказал', 'сказать', 'V', 'V,сов,пе=прош,ед,изъяв,муж', 'OUT'],
#  [59, 'книжка', 'книжка', 'S', 'S,жен,неод=им,ед', 'OUT'],
#  [59,
#   'написана',
#   'написать',
#   'V',
#   'V,сов,пе=прош,ед,прич,кр,жен,страд',
#   'OUT'],
#  [59,
#   'целых',
#   'целый',
#   'A=pl',
#   'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)',
#   'OUT'],
#  [59, 'сто', 'сто', 'ADV', 'NUM=(вин|им)', 'OUT'],
#  [59, 'лет', 'год', 'S', 'S,муж,неод=род,мн', 'OUT'],
#  [59, 'назад', 'назад', 'ADV', 'ADV=', 'OUT'],
#  [60, 'знать', 'знать', 'V', 'V,несов,пе=инф', 'OUT'],
#  [60,
#   'вещи',
#   'вещь',
#   'S',
#   'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)',
#   'OUT'],
#  [60, 'по-моему', 'по-моему', 'ADV-PRO', 'ADV,вводн=', 'OUT'],
#  [60, 'никто', 'никто', 'S-PRO', 'SPRO,ед,муж,од=им', 'OUT'],
#  [60,
#   'малый',
#   'малый',
#   'A=m',
#   'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)',
#   'OUT'],
#  [60,
#   'энциклопедический',
#   'энциклопедический',
#   'A=m',
#   'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)',
#   'OUT'],
#  [60, 'словарь', 'словарь', 'S', 'S,муж,неод=(вин,ед|им,ед)', 'OUT'],
#  [61, 'советую', 'советовать', 'V', 'V,несов,нп=непрош,ед,изъяв,1-л', 'OUT'],
#  [61, 'внимательно', 'внимательно', 'ADV', 'ADV=', 'OUT'],
#  [61, 'прочитать', 'прочитывать', 'V', 'V=инф,сов', 'OUT'],
#  [61,
#   'примечания',
#   'примечание',
#   'S',
#   'S,сред,неод=(вин,мн|род,ед|им,мн)',
#   'OUT'],
#  [61,
#   'напечатаны',
#   'напечатать',
#   'V',
#   'V,сов,пе=прош,мн,прич,кр,страд',
#   'OUT'],
#  [61,
#   'мелким',
#   'мелкий',
#   'A=m',
#   'A=(дат,мн,полн|твор,ед,полн,муж|твор,ед,полн,сред)',
#   'OUT'],
#  [61, 'шрифтом', 'шрифт', 'S', 'S,муж,неод=твор,ед', 'OUT'],
#  [61, 'это', 'это', 'S-PRO', 'SPRO,ед,сред,неод=(вин|им)', 'OUT'],
#  [61, 'кое', 'кое', 'A=n', 'COM=', 'OUT'],
#  [61, 'помочь', 'помогать', 'V', 'V,нп=инф,сов', 'OUT'],
#  [62, 'поэтому', 'поэтому', 'ADV-PRO', 'ADVPRO=', 'OUT'],
#  [62,
#   'что-нибудь',
#   'что-нибудь',
#   'S-PRO',
#   'SPRO,ед,сред,неод=(вин|им)',
#   'OUT'],
#  [62, 'покажется', 'показываться', 'V', 'V,нп=непрош,ед,изъяв,3-л,сов', 'OUT'],
#  [62, 'очень', 'очень', 'ADV', 'ADV=', 'OUT'],
#  [62,
#   'непонятным',
#   'непонятный',
#   'A=n',
#   'A=(дат,мн,полн|твор,ед,полн,муж|твор,ед,полн,сред)',
#   'OUT'],
#  [62, 'главное', 'главное', 'A=n', 'ADV,вводн=', 'OUT'],
#  [62,
#   'смешным',
#   'смешной',
#   'A=n',
#   'A=(дат,мн,полн|твор,ед,полн,муж|твор,ед,полн,сред)',
#   'OUT'],
#  [62, 'стесняйтесь', 'стесняться', 'V', 'V,нп=мн,пов,2-л,несов', 'OUT'],
#  [62, 'спрашивать', 'спрашивать', 'V', 'V=инф,несов,пе', 'OUT'],
#  [62, 'старших', 'старший', 'A=pl', 'S,муж,од=(пр,мн|вин,мн|род,мн)', 'OUT'],
#  [63, 'это', 'это', 'S-PRO', 'SPRO,ед,сред,неод=(вин|им)', 'OUT'],
#  [63, 'знают', 'знать', 'V', 'V,несов,пе=непрош,мн,изъяв,3-л', 'OUT'],
#  [63, 'понятно', 'понятно', 'PRAEDIC', 'ADV=вводн', 'OUT'],
#  [63, 'кое', 'кой', 'A=n', 'APRO=(вин,ед,сред|им,ед,сред)', 'OUT'],
#  [63,
#   'задумаетесь',
#   'задумываться',
#   'V',
#   'V,нп=непрош,мн,изъяв,2-л,сов',
#   'OUT'],
#  [64, 'это', 'это', 'S-PRO', 'PART=', 'OUT'],
#  [64, 'обязательно', 'обязательно', 'ADV', 'ADV=', 'OUT'],
#  [65, 'надеюсь', 'надеяться', 'V', 'V,несов,нп=непрош,ед,изъяв,1-л', 'OUT'],
#  [65, 'захотелось', 'захотеться', 'V', 'V,сов,нп=прош,ед,изъяв,сред', 'OUT'],
#  [65, 'узнать', 'узнавать', 'V', 'V,пе=инф,сов', 'OUT'],
#  [65, 'появилась', 'появляться', 'V', 'V,нп=прош,ед,изъяв,жен,сов', 'OUT'],
#  [65, 'свет', 'свет', 'S', 'S,ед,муж,неод=(вин|им)', 'OUT'],
#  [65, 'такая', 'такой', 'A-PRO=f', 'APRO=им,ед,жен', 'OUT'],
#  [65, 'необыкновенная', 'необыкновенный', 'A=f', 'A=им,ед,полн,жен', 'OUT'],
#  [65, 'сказка', 'сказка', 'S', 'S,жен,неод=им,ед', 'OUT'],
#  [65, 'сочинил', 'сочинять', 'V', 'V,пе=прош,ед,изъяв,муж,сов', 'OUT'],
#  [66, 'сочинить', 'сочинять', 'V', 'V,пе=инф,сов', 'OUT'],
#  [66, 'такую', 'такой', 'A-PRO=f', 'APRO=вин,ед,жен', 'OUT'],
#  [66, 'сказку', 'сказка', 'S', 'S,жен,неод=вин,ед', 'OUT'],
#  [66, 'мог', 'мочь', 'V', 'V,несов,нп=прош,ед,изъяв,муж', 'OUT'],
#  [66,
#   'необыкновенный',
#   'необыкновенный',
#   'A=m',
#   'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)',
#   'OUT'],
#  [66, 'человек', 'человек', 'S', 'S,муж,од=(вин,мн|род,мн|им,ед)', 'OUT'],
#  [67, 'неизвестно', 'неизвестно', 'PRAEDIC', 'ADV=', 'OUT'],
#  [67, 'сочинил', 'сочинять', 'V', 'V,пе=прош,ед,изъяв,муж,сов', 'OUT'],
#  [67, 'одна', 'один', 'A-PRO=f', 'APRO=им,ед,жен', 'OUT'],
#  [67, 'маленькая', 'маленький', 'A=f', 'A=им,ед,полн,жен', 'OUT'],
#  [67, 'девочка', 'девочка', 'S', 'S,жен,од=им,ед', 'OUT'],
#  [67, 'которую', 'который', 'A-PRO=f', 'APRO=вин,ед,жен', 'OUT'],
#  [67, 'звали', 'звать', 'V', 'V,несов,пе=прош,мн,изъяв', 'OUT'],
#  [68, 'угадайте', 'угадывать', 'V', 'V,пе=мн,пов,2-л,сов', 'OUT'],
#  [69, 'правильно', 'правильно', 'ADV', 'ADV=', 'OUT'],
#  [69, 'алисой', 'алиса', 'A=f', 'S,имя,жен,од=твор,ед', 'OUT'],
#  [70, 'именно', 'именно', 'PART', 'PART=', 'OUT'],
#  [70, 'алиса', 'алиса', 'S', 'S,имя,жен,од=им,ед', 'OUT'],
#  [70, 'потребовала', 'потребовать', 'V', 'V,сов,пе=прош,ед,изъяв,жен', 'OUT'],
#  [70, 'время', 'время', 'S', 'S,сред,неод=(вин,ед|им,ед)', 'OUT'],
#  [70,
#   'лодочной',
#   'лодочный',
#   'A=f',
#   'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)',
#   'OUT'],
#  [70, 'прогулки', 'прогулка', 'S', 'S,жен,неод=(вин,мн|род,ед|им,мн)', 'OUT'],
#  [70,
#   'своего',
#   'свой',
#   'A-PRO=m',
#   'APRO=(вин,ед,муж,од|род,ед,муж|род,ед,сред)',
#   'OUT'],
#  [70,
#   'знакомого',
#   'знакомый',
#   'A=n',
#   'A=(вин,ед,полн,муж,од|род,ед,полн,муж|род,ед,полн,сред)',
#   'OUT'],
#  [70, 'мистера', 'мистер', 'S', 'S,муж,од=(вин,ед|род,ед)', 'OUT'],
#  [70, 'доджсона', 'доджсон', 'S', 'S,фам,муж,од=(вин,ед|род,ед)', 'OUT'],
#  [70, 'рассказал', 'рассказывать', 'V', 'V=прош,ед,изъяв,муж,сов', 'OUT'],
#  [70, 'сестрам', 'сестра', 'S', 'S,жен,од=дат,мн', 'OUT'],
#  [70, 'интересную', 'интересный', 'A=f', 'A=вин,ед,полн,жен', 'OUT'],
#  [70, 'сказку', 'сказка', 'S', 'S,жен,неод=вин,ед', 'OUT'],
#  [71, 'сказке', 'сказка', 'S', 'S,жен,неод=(пр,ед|дат,ед)', 'OUT'],
#  [71, 'побольше', 'много', 'A=comp2', 'ADV=срав', 'OUT'],
#  [71,
#   'веселой',
#   'веселый',
#   'A=f',
#   'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)',
#   'OUT'],
#  [71, 'чепухи', 'чепуха', 'S', 'S,жен,неод=(вин,мн|род,ед|им,мн)', 'OUT'],
#  [72, 'видно', 'видно', 'PRAEDIC', 'ADV,прдк=', 'OUT'],
#  [72, 'эта', 'этот', 'A-PRO=f', 'APRO=им,ед,жен', 'OUT'],
#  [72, 'алиса', 'алиса', 'S', 'S,имя,жен,од=им,ед', 'OUT'],
#  [72, 'такая', 'такой', 'A-PRO=f', 'APRO=им,ед,жен', 'OUT'],
#  [72, 'девочка', 'девочка', 'S', 'S,жен,од=им,ед', 'OUT'],
#  [72,
#   'которой',
#   'который',
#   'A-PRO=f',
#   'APRO=(пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен)',
#   'OUT'],
#  [72, 'очень', 'очень', 'ADV', 'ADV=', 'OUT'],
#  [72, 'трудно', 'трудно', 'PRAEDIC', 'ADV=', 'OUT'],
#  [72, 'отказать', 'отказывать', 'V', 'V,нп=инф,сов', 'OUT'],
#  [72, 'мистер', 'мистер', 'S', 'S,муж,од=им,ед', 'OUT'],
#  [72, 'доджсон', 'доджсон', 'S', 'S,фам,муж,од=им,ед', 'OUT'],
#  [72, 'хотя', 'хотя', 'CONJ', 'CONJ=', 'OUT'],
#  [72, 'профессором', 'профессор', 'S', 'S,муж,од=твор,ед', 'OUT'],
#  [72,
#   'математики',
#   'математика',
#   'S',
#   'S,жен,неод=(вин,мн|род,ед|им,мн)',
#   'OUT'],
#  [72,
#   'честное',
#   'честный',
#   'A=n',
#   'A=(вин,ед,полн,сред|им,ед,полн,сред)',
#   'OUT'],
#  [72, 'слово', 'слово', 'S', 'S,сред,неод=(вин,ед|им,ед)', 'OUT'],
#  [72, 'тому', 'то', 'A-PRO=m', 'SPRO,ед,сред,неод=дат', 'OUT'],
#  [72, 'день', 'день', 'S', 'S,муж,неод=(вин,ед|им,ед)', 'OUT'],
#  [72, 'сильно', 'сильно', 'ADV', 'ADV=', 'OUT'],
#  [72, 'устал', 'уставать', 'V', 'V,нп=прош,ед,изъяв,муж,сов', 'OUT'],
#  [72, 'послушался', 'послушаться', 'V', 'V,сов,нп=прош,ед,изъяв,муж', 'OUT'],
#  [73, 'начал', 'начинать', 'V', 'V,пе=прош,ед,изъяв,муж,сов', 'OUT'],
#  [73, 'рассказывать', 'рассказывать', 'V', 'V=инф,несов,пе', 'OUT'],
#  [73, 'сказку', 'сказка', 'S', 'S,жен,неод=вин,ед', 'OUT'],
#  [73, 'приключениях', 'приключение', 'S', 'S,сред,неод=пр,мн', 'OUT'],
#  [73,
#   'одной',
#   'один',
#   'ANUM=f',
#   'APRO=(пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен)',
#   'OUT'],
#  [73, 'девочки', 'девочка', 'S', 'S,жен,од=(род,ед|им,мн)', 'OUT'],
#  [73, 'которую', 'который', 'A-PRO=f', 'APRO=вин,ед,жен', 'OUT'],
#  [73, 'почему-то', 'почему-то', 'ADV-PRO', 'ADVPRO=', 'OUT'],
#  [73, 'звали', 'звать', 'V', 'V,несов,пе=прош,мн,изъяв', 'OUT'],
#  [73, 'алисой', 'алиса', 'A=f', 'S,имя,жен,од=твор,ед', 'OUT'],
#  [74, 'отдать', 'отдавать', 'V', 'V,пе=инф,сов', 'OUT'],
#  [74, 'должное', 'должное', 'A=n', 'S,сред,неод=(вин,ед|им,ед)', 'OUT'],
#  [74,
#   'маленькой',
#   'маленький',
#   'A=f',
#   'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)',
#   'OUT'],
#  [74, 'алисе', 'алиса', 'S', 'S,имя,жен,од=(пр,ед|дат,ед)', 'OUT'],
#  [74, 'имею', 'иметь', 'V', 'V,несов,пе=непрош,ед,изъяв,1-л', 'OUT'],
#  [74, 'виду', 'вид', 'S', 'S,муж,неод=(дат,ед|парт,ед|местн,ед)', 'OUT'],
#  [74, 'живую', 'живой', 'A=f', 'A=вин,ед,полн,жен', 'OUT'],
#  [74, 'алису', 'алиса', 'S', 'S,имя,жен,од=вин,ед', 'OUT'],
#  [74, 'полностью', 'полностью', 'ADV', 'ADV=', 'OUT'],
#  [74, 'звали', 'звать', 'V', 'V,несов,пе=прош,мн,изъяв', 'OUT'],
#  [74, 'алиса', 'алиса', 'S', 'S,имя,жен,од=им,ед', 'OUT'],
#  [74, 'плезенс', 'плезенс', 'V', 'S,муж,неод=(вин,ед|им,ед)', 'OUT'],
#  [74, 'лиддел', 'лиддевать', 'V', 'V,пе=прош,ед,изъяв,муж,сов', 'OUT'],
#  [74, 'знала', 'знать', 'V', 'V,несов,пе=прош,ед,изъяв,жен', 'OUT'],
#  [74, 'кого', 'кто', 'S-PRO', 'SPRO,ед,муж,од=(вин|род)', 'OUT'],
#  [74, 'попросить', 'попросить', 'V', 'V,сов,пе=инф', 'OUT'],
#  [74, 'рассказать', 'рассказывать', 'V', 'V=инф,сов', 'OUT'],
#  [74, 'сказку', 'сказка', 'S', 'S,жен,неод=вин,ед', 'OUT'],
#  [75, 'взрослые', 'взрослый', 'A=pl', 'S,муж,од=им,мн', 'OUT'],
#  [75, 'особенно', 'особенно', 'ADV', 'ADV=', 'OUT'],
#  [75, 'те', 'тот', 'A-PRO=pl', 'APRO=(им,мн|вин,мн,неод)', 'OUT'],
#  [75, 'которые', 'который', 'A-PRO=pl', 'APRO=(им,мн|вин,мн,неод)', 'OUT'],
#  [75, 'понимают', 'понимать', 'V', 'V=непрош,мн,изъяв,3-л,несов,пе', 'OUT'],
#  [75, 'считали', 'считать', 'V', 'V,несов,пе=прош,мн,изъяв', 'OUT'],
#  [75, 'мистера', 'мистер', 'S', 'S,муж,од=(вин,ед|род,ед)', 'OUT'],
#  [75, 'доджсона', 'доджсон', 'S', 'S,фам,муж,од=(вин,ед|род,ед)', 'OUT'],
#  [75,
#   'скучным',
#   'скучный',
#   'A=n',
#   'A=(дат,мн,полн|твор,ед,полн,муж|твор,ед,полн,сред)',
#   'OUT'],
#  [75, 'человеком', 'человек', 'S', 'S,муж,од=твор,ед', 'OUT'],
#  [75,
#   'сухим',
#   'сухой',
#   'A=pl',
#   'A=(дат,мн,полн|твор,ед,полн,муж|твор,ед,полн,сред)',
#   'OUT'],
#  [75, 'математиком', 'математик', 'S', 'S,муж,од=твор,ед', 'OUT'],
#  [75, 'увы', 'увы', 'INTJ', 'INTJ=', 'OUT'],
#  [75, 'студенты', 'студент', 'S', 'S,муж,од=им,мн', 'OUT'],
#  [75, 'особенно', 'особенно', 'ADV', 'ADV=', 'OUT'],
#  [75, 'любили', 'любить', 'V', 'V,несов,пе=прош,мн,изъяв', 'OUT'],
#  [75,
#   'лекции',
#   'лекция',
#   'S',
#   'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)',
#   'OUT'],
#  [76, 'маленькая', 'маленький', 'A=f', 'A=им,ед,полн,жен', 'OUT'],
#  [76, 'алиса', 'алиса', 'S', 'S,имя,жен,од=им,ед', 'OUT'],
#  [76, 'те', 'тот', 'A-PRO=pl', 'APRO=(им,мн|вин,мн,неод)', 'OUT'],
#  [76, 'дети', 'ребенок', 'S', 'S,муж,од=им,мн', 'OUT'],
#  [76,
#   'англии',
#   'англия',
#   'S',
#   'S,гео,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)',
#   'OUT'],
#  [76,
#   'которым',
#   'который',
#   'A-PRO=m',
#   'APRO=(дат,мн|твор,ед,муж|твор,ед,сред)',
#   'OUT'],
#  [76,
#   'посчастливилось',
#   'посчастливиться',
#   'V',
#   'V,сов,нп=прош,ед,изъяв,сред',
#   'OUT'],
#  [76, 'встретиться', 'встречаться', 'V', 'V,нп=инф,сов', 'OUT'],
#  [76, 'мистером', 'мистер', 'S', 'S,муж,од=твор,ед', 'OUT'],
#  [76, 'чарльзом', 'чарльз', 'S', 'S,имя,муж,од=твор,ед', 'OUT'],
#  [76, 'лютвиджем', 'лютвидж', 'V', 'S,муж,неод=твор,ед', 'OUT'],
#  [76, 'доджсоном', 'доджсон', 'A=n', 'S,фам,муж,од=твор,ед', 'OUT'],
#  [76, 'звали', 'звать', 'V', 'V,несов,пе=прош,мн,изъяв', 'OUT'],
#  [76, 'выдумал', 'выдумывать', 'V', 'V,пе=прош,ед,изъяв,муж,сов', 'OUT'],
#  [76, 'прекрасно', 'прекрасно', 'ADV', 'ADV=', 'OUT'],
#  [76, 'знала', 'знать', 'V', 'V,несов,пе=прош,ед,изъяв,жен', 'OUT'],
#  [76, 'вовсе', 'вовсе', 'ADV', 'ADV=', 'OUT'],
#  [76, 'это', 'это', 'S-PRO', 'SPRO,ед,сред,неод=(вин|им)', 'OUT'],
#  [76, 'неправда', 'неправда', 'ADV', 'S,жен,неод=им,ед', 'OUT'],
#  [77, 'считать', 'считать', 'V', 'V,несов,пе=инф', 'OUT'],
#  [77,
#   'скучным',
#   'скучный',
#   'A=n',
#   'A=(дат,мн,полн|твор,ед,полн,муж|твор,ед,полн,сред)',
#   'OUT'],
#  [77, 'человека', 'человек', 'S', 'S,муж,од=(вин,ед|род,ед)', 'OUT'],
#  [77,
#   'который',
#   'который',
#   'A-PRO=m',
#   'APRO=(вин,ед,муж,неод|им,ед,муж)',
#   'OUT'],
#  [77, 'умел', 'уметь', 'V', 'V,несов,нп=прош,ед,изъяв,муж', 'OUT'],
#  [77, 'сделать', 'сделать', 'V', 'V,сов,пе=инф', 'OUT'],
#  [77,
#   'носового',
#   'носовой',
#   'A=n',
#   'A=(вин,ед,полн,муж,од|род,ед,полн,муж|род,ед,полн,сред)',
#   'OUT'],
#  [77, 'платка', 'платок', 'S', 'S,муж,неод=род,ед', 'OUT'],
#  [77, 'мышь', 'мышь', 'V', 'S,жен,од=(вин,ед|им,ед)', 'OUT'],
#  [77, 'эта', 'этот', 'A-PRO=f', 'APRO=им,ед,жен', 'OUT'],
#  [77, 'мышь', 'мышь', 'V', 'S,жен,од=(вин,ед|им,ед)', 'OUT'],
#  [77, 'бегала', 'бегать', 'V', 'V,несов,нп=прош,ед,изъяв,жен', 'OUT'],
#  [77, 'живая', 'живой', 'A=f', 'A=им,ед,полн,жен', 'OUT'],
#  [78, 'человека', 'человек', 'S', 'S,муж,од=(вин,ед|род,ед)', 'OUT'],
#  [78,
#   'который',
#   'который',
#   'A-PRO=m',
#   'APRO=(вин,ед,муж,неод|им,ед,муж)',
#   'OUT'],
#  [78,
#   'простой',
#   'простой',
#   'A=m',
#   'A=(вин,ед,полн,муж,неод|им,ед,полн,муж|пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)',
#   'OUT'],
#  [78, 'бумаги', 'бумага', 'S', 'S,жен,неод=(вин,мн|род,ед|им,мн)', 'OUT'],
#  [78, 'складывал', 'складывать', 'V', 'V,несов,пе=прош,ед,изъяв,муж', 'OUT'],
#  [78, 'пистолет', 'пистолет', 'S', 'S,муж,неод=(вин,ед|им,ед)', 'OUT'],
#  [78, 'пистолет', 'пистолет', 'S', 'S,муж,неод=(вин,ед|им,ед)', 'OUT'],
#  [78, 'стрелял', 'стрелять', 'V', 'V,несов,пе=прош,ед,изъяв,муж', 'OUT'],
#  [78, 'худее', 'худой', 'A=pl', 'A=срав', 'OUT'],
#  [78,
#   'настоящего',
#   'настоящий',
#   'A=n',
#   'A=(вин,ед,полн,муж,од|род,ед,полн,муж|род,ед,полн,сред)',
#   'OUT'],
#  [79, 'считать', 'считать', 'V', 'V,несов,пе=инф', 'OUT'],
#  [79,
#   'скучным',
#   'скучный',
#   'A=n',
#   'A=(дат,мн,полн|твор,ед,полн,муж|твор,ед,полн,сред)',
#   'OUT'],
#  [79,
#   'такого',
#   'такой',
#   'A-PRO=m',
#   'APRO=(вин,ед,муж,од|род,ед,муж|род,ед,сред)',
#   'OUT'],
#  [79,
#   'необыкновенного',
#   'необыкновенный',
#   'A=n',
#   'A=(вин,ед,полн,муж,од|род,ед,полн,муж|род,ед,полн,сред)',
#   'OUT'],
#  [79, 'выдумщика', 'выдумщик', 'S', 'S,муж,од=(вин,ед|род,ед)', 'OUT'],
#  [80, 'выдумывал', 'выдумывать', 'V', 'V,пе=прош,ед,изъяв,муж,несов', 'OUT'],
#  [80, 'сказки', 'сказка', 'S', 'S,жен,неод=(вин,мн|род,ед|им,мн)', 'OUT'],
#  [80, 'выдумывал', 'выдумывать', 'V', 'V,пе=прош,ед,изъяв,муж,несов', 'OUT'],
#  [80,
#   'головоломки',
#   'головоломка',
#   'S',
#   'S,жен,неод=(вин,мн|род,ед|им,мн)',
#   'OUT'],
#  [80, 'загадки', 'загадка', 'S', 'S,жен,неод=(вин,мн|род,ед|им,мн)', 'OUT'],
#  [80, 'игрушки', 'игрушка', 'S', 'S,жен,неод=(вин,мн|род,ед|им,мн)', 'OUT'],
#  [80, 'игры', 'игра', 'S', 'S,жен,неод=(вин,мн|род,ед|им,мн)', 'OUT'],
#  [80, 'какие', 'какой', 'A-PRO=pl', 'APRO=(им,мн|вин,мн,неод)', 'OUT'],
#  [81, 'некоторые', 'некоторый', 'A-PRO=pl', 'APRO=(им,мн|вин,мн,неод)', 'OUT'],
#  [81, 'играют', 'играть', 'V', 'V,несов,пе=непрош,мн,изъяв,3-л', 'OUT'],
#  [81, 'сих', 'сей', 'A-PRO=pl', 'APRO=(пр,мн|род,мн|вин,мн,од)', 'OUT'],
#  [81, 'пор', 'пора', 'S', 'S,жен,неод=род,мн', 'OUT'],
#  [82, 'именно', 'именно', 'PART', 'PART=', 'OUT'],
#  [82, 'придумал', 'придумывать', 'V', 'V,пе=прош,ед,изъяв,муж,сов', 'OUT'],
#  [82, 'веселую', 'веселый', 'A=f', 'A=вин,ед,полн,жен', 'OUT'],
#  [82, 'игру', 'игра', 'S', 'S,жен,неод=вин,ед', 'OUT'],
#  [82, 'которая', 'который', 'A-PRO=f', 'APRO=им,ед,жен', 'OUT'],
#  [82,
#   'называется',
#   'называться',
#   'V',
#   'V,несов,нп=непрош,ед,изъяв,3-л',
#   'OUT'],
#  [82, 'цепочка', 'цепочка', 'S', 'S,жен,неод=им,ед', 'OUT'],
#  [82, 'сделать', 'сделать', 'V', 'V,сов,пе=инф', 'OUT'],
#  [82, 'мухи', 'муха', 'S', 'S,жен,од=(род,ед|им,мн)', 'OUT'],
#  [82, 'слона', 'слон', 'S', 'S,муж,од=(вин,ед|род,ед)', 'OUT'],
#  [82, 'умеет', 'уметь', 'V', 'V,несов,нп=непрош,ед,изъяв,3-л', 'OUT'],
#  [82, 'играть', 'играть', 'V', 'V,несов,пе=инф', 'OUT'],
#  [82, 'легко', 'легко', 'ADV', 'ADV=', 'OUT'],
#  [82, 'превратить', 'превращать', 'V', 'V,пе=инф,сов', 'OUT'],
#  [82, 'ночь', 'ночь', 'S', 'S,жен,неод=(вин,ед|им,ед)', 'OUT'],
#  [82, 'день', 'день', 'S', 'S,муж,неод=(вин,ед|им,ед)', 'OUT'],
#  [82, 'море', 'море', 'S', 'S,сред,неод=(пр,ед|вин,ед|им,ед)', 'OUT'],
#  [82, 'гору', 'гора', 'S', 'S,жен,неод=вин,ед', 'OUT'],
#  [83, 'море', 'море', 'S', 'S,сред,неод=(пр,ед|вин,ед|им,ед)', 'OUT'],
#  [83, 'горе', 'горе', 'S', 'S,ед,сред,неод=(пр|вин|им)', 'OUT'],
#  [83, 'гора', 'гора', 'S', 'S,жен,неод=им,ед', 'OUT'],
#  [85, 'можете', 'мочь', 'V', 'V,несов,нп=непрош,мн,изъяв,2-л', 'OUT'],
#  [85, 'играть', 'играть', 'V', 'V,несов,пе=инф', 'OUT'],
#  [85, 'уроках', 'урок', 'S', 'S,муж,неод=пр,мн', 'OUT'],
#  [86, 'особенно', 'особенно', 'ADV', 'ADV=', 'OUT'],
#  [86, 'любил', 'любить', 'V', 'V,несов,пе=прош,ед,изъяв,муж', 'OUT'],
#  [86, 'умел', 'уметь', 'V', 'V,несов,нп=прош,ед,изъяв,муж', 'OUT'],
#  [86, 'играть', 'играть', 'V', 'V,несов,пе=инф', 'OUT'],
#  [87, 'словами', 'слово', 'S', 'S,сред,неод=твор,мн', 'OUT'],
#  [88, 'самые', 'самый', 'A-PRO=pl', 'APRO=(им,мн|вин,мн,неод)', 'OUT'],
#  [88,
#   'серьезные',
#   'серьезный',
#   'A=pl',
#   'A=(вин,мн,полн,неод|им,мн,полн)',
#   'OUT'],
#  [88, 'самые', 'самый', 'A-PRO=pl', 'APRO=(им,мн|вин,мн,неод)', 'OUT'],
#  [88,
#   'солидные',
#   'солидный',
#   'A=pl',
#   'A=(вин,мн,полн,неод|им,мн,полн)',
#   'OUT'],
#  [88, 'самые', 'самый', 'A-PRO=pl', 'APRO=(им,мн|вин,мн,неод)', 'OUT'],
#  [88, 'трудные', 'трудный', 'A=pl', 'A=(вин,мн,полн,неод|им,мн,полн)', 'OUT'],
#  [88, 'слова', 'слово', 'S', 'S,сред,неод=(вин,мн|род,ед|им,мн)', 'OUT'],
#  [88, 'приказу', 'приказ', 'V', 'S,муж,неод=дат,ед', 'OUT'],
#  [88, 'кувыркались', 'кувыркаться', 'V', 'V,несов,нп=прош,мн,изъяв', 'OUT'],
#  [88, 'ходили', 'ходить', 'V', 'V,несов,нп=прош,мн,изъяв', 'OUT'],
#  [88, 'голове', 'голова', 'S', 'S,жен,неод=(пр,ед|дат,ед)', 'OUT'],
#  [88, 'показывали', 'показывать', 'V', 'V=прош,мн,изъяв,несов,пе', 'OUT'],
#  [88, 'фокусы', 'фокус', 'S', 'S,муж,неод=(вин,мн|им,мн)', 'OUT'],
#  [88, 'превращались', 'превращаться', 'V', 'V,нп=прош,мн,изъяв,несов', 'OUT'],
#  [88, 'одно', 'один', 'A-PRO=n', 'APRO=(вин,ед,сред|им,ед,сред)', 'OUT'],
#  [88, 'другое', 'другой', 'A-PRO=n', 'APRO=(вин,ед,сред|им,ед,сред)', 'OUT'],
#  [88, 'словом', 'словом', 'PARENTH', 'ADV,вводн=', 'OUT'],
#  [88, 'бог', 'бог', 'S', 'S,муж,од=им,ед', 'OUT'],
#  [88, 'знает', 'знать', 'V', 'V,несов,пе=непрош,ед,изъяв,3-л', 'OUT'],
#  [88, 'выделывали', 'выделывать', 'V', 'V,пе=прош,мн,изъяв,несов', 'OUT'],
#  [89, 'умел', 'уметь', 'V', 'V,несов,нп=прош,ед,изъяв,муж', 'OUT'],
#  [89, 'переделывать', 'переделывать', 'V', 'V,пе=инф,несов', 'OUT'],
#  [89, 'старые', 'старый', 'A=pl', 'A=(вин,мн,полн,неод|им,мн,полн)', 'OUT'],
#  [89,
#   'надоевшие',
#   'надоедать',
#   'A=pl',
#   'V,нп=(прош,им,мн,прич,полн,сов,действ|прош,вин,мн,прич,полн,сов,действ,неод)',
#   'OUT'],
#  [89, 'стишки', 'стишок', 'S', 'S,муж,неод=(вин,мн|им,мн)', 'OUT'],
# ...
#  [98, 'название', 'название', 'S', 'S,сред,неод=(вин,ед|им,ед)', 'OUT'],
#  [98, 'алиса', 'алиса', 'S', 'S,имя,жен,од=им,ед', 'OUT'],
#  [98, 'стране', 'страна', 'S', 'S,жен,неод=(пр,ед|дат,ед)', 'OUT'],
#  [98, 'чудес', 'чудо', 'S', 'S,сред,неод=род,мн', 'OUT'],
#  [98, 'убеждался', 'убеждаться', 'V', 'V,нп=прош,ед,изъяв,муж,несов', 'OUT'],
#  [99, 'никак', 'никак', 'ADV-PRO', 'ADVPRO,вводн=', 'OUT'],
#  [99, 'заставить', 'заставлять', 'V', 'V,пе=инф,сов', 'OUT'],
#  [99, 'русские', 'русский', 'A=pl', 'A=(вин,мн,полн,неод|им,мн,полн)', 'OUT'],
#  [99, 'слова', 'слово', 'S', 'S,сред,неод=(вин,мн|род,ед|им,мн)', 'OUT'],
#  [99, 'играть', 'играть', 'V', 'V,несов,пе=инф', 'OUT'],
#  [99, 'те', 'тот', 'A-PRO=pl', 'APRO=(им,мн|вин,мн,неод)', 'OUT'],
#  [99, 'игры', 'игра', 'S', 'S,жен,неод=(вин,мн|род,ед|им,мн)', 'OUT'],
#  [99, 'показывать', 'показывать', 'V', 'V=инф,несов,пе', 'OUT'],
#  [99, 'те', 'тот', 'A-PRO=pl', 'APRO=(им,мн|вин,мн,неод)', 'OUT'],
#  [99, 'фокусы', 'фокус', 'S', 'S,муж,неод=(вин,мн|им,мн)', 'OUT'],
#  [99, 'какие', 'какой', 'A-PRO=pl', 'APRO=(им,мн|вин,мн,неод)', 'OUT'],
#  [99, 'проделывали', 'проделывать', 'V', 'V,пе=прош,мн,изъяв,несов', 'OUT'],
#  [99,
#   'английские',
#   'английский',
#   'A=pl',
#   'A=(вин,мн,полн,неод|им,мн,полн)',
#   'OUT'],
#  [99, 'слова', 'слово', 'S', 'S,сред,неод=(вин,мн|род,ед|им,мн)', 'OUT'],
#  [99,
#   'волшебным',
#   'волшебный',
#   'A=m',
#   'A=(дат,мн,полн|твор,ед,полн,муж|твор,ед,полн,сред)',
#   'OUT'],
#  [99, 'пером', 'перо', 'S', 'S,сред,неод=твор,ед', 'OUT'],
#  [99, 'кэрролла', 'кэрролл', 'S', 'S,фам,муж,од=(вин,ед|род,ед)', 'OUT'],
#  [100, 'фокусы', 'фокус', 'S', 'S,муж,неод=(вин,мн|им,мн)', 'OUT'],
#  [100, 'грехом', 'грех', 'S', 'S,муж,неод=твор,ед', 'OUT'],
#  [100, 'пополам', 'пополам', 'ADV', 'ADV=', 'OUT'],
#  [100, 'получались', 'получаться', 'V', 'V,нп=прош,мн,изъяв,несов', 'OUT'],
#  [100, 'что-то', 'что-то', 'S-PRO', 'SPRO,ед,сред,неод=(вин|им)', 'OUT'],
#  [100, 'самое', 'самый', 'A-PRO=n', 'APRO=(вин,ед,сред|им,ед,сред)', 'OUT'],
#  [100, 'главное', 'главное', 'A=n', 'S,сред,неод=(вин,ед|им,ед)', 'OUT'],
#  [100, 'пропадало', 'пропадать', 'V', 'V,нп=прош,ед,изъяв,сред,несов', 'OUT'],
#  [100, 'веселая', 'веселый', 'A=f', 'A=им,ед,полн,жен', 'OUT'],
#  [100, 'умная', 'умный', 'A=f', 'A=им,ед,полн,жен', 'OUT'],
#  [100, 'озорная', 'озорной', 'A=f', 'A=им,ед,полн,жен', 'OUT'],
#  [100, 'расчудесная', 'расчудесный', 'A=f', 'A=им,ед,полн,жен', 'OUT'],
#  [100, 'сказка', 'сказка', 'S', 'S,жен,неод=им,ед', 'OUT'],
#  [100,
#   'становилась',
#   'становиться',
#   'V',
#   'V,нп=прош,ед,изъяв,жен,несов',
#   'OUT'],
#  [100,
#   'малопонятной',
#   'малопонятный',
#   'A=f',
#   'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)',
#   'OUT'],
#  [100, 'страшно', 'страшно', 'PRAEDIC', 'ADV=', 'OUT'],
#  [100, 'сказать', 'сказать', 'V', 'V,сов,пе=инф', 'OUT'],
#  [100,
#   'скучной',
#   'скучный',
#   'A=f',
#   'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)',
#   'OUT'],
#  [101, 'друзья', 'друг', 'S', 'S,муж,од=им,мн', 'OUT'],
#  [101, 'говорили', 'говорить', 'V', 'V,несов,пе=прош,мн,изъяв', 'OUT'],
#  [101, 'пора', 'пора', 'PRAEDIC', 'ADV,прдк=', 'OUT'],
#  [101, 'тебе', 'ты', 'S-PRO', 'SPRO,ед,2-л=(пр|дат)', 'OUT'],
#  [101, 'перевести', 'переводить', 'V', 'V=инф,сов', 'OUT'],
#  [101, 'алису', 'алиса', 'S', 'S,имя,жен,од=вин,ед', 'OUT'],
#  [102, 'неужели', 'неужели', 'PART', 'PART=', 'OUT'],
#  [102, 'тебе', 'ты', 'S-PRO', 'SPRO,ед,2-л=(пр|дат)', 'OUT'],
#  [102, 'хочется', 'хотеться', 'V', 'V,несов,нп=непрош,изъяв', 'OUT'],
#  [102, 'очень', 'очень', 'ADV', 'ADV=', 'OUT'],
#  [102, 'хочется', 'хотеться', 'V', 'V,несов,нп=непрош,изъяв', 'OUT'],
#  [102, 'отвечал', 'отвечать', 'V', 'V,нп=прош,ед,изъяв,муж,несов', 'OUT'],
#  [102, 'успел', 'успевать', 'V', 'V,нп=прош,ед,изъяв,муж,сов', 'OUT'],
#  [102, 'убедиться', 'убеждаться', 'V', 'V,нп=инф,сов', 'OUT'],
#  [102, 'пожалуй', 'пожалуй', 'PARENTH', 'PART,вводн=', 'OUT'],
#  [102, 'легче', 'легко', 'PRAEDIC=comp', 'ADV=срав', 'OUT'],
#  [103, 'перевезти', 'перевозить', 'V', 'V=инф,сов', 'OUT'],
#  [103, 'англию', 'англия', 'S', 'S,гео,жен,неод=вин,ед', 'OUT'],
#  [104, 'уверен', 'уверенный', 'A=m', 'A=ед,кр,муж', 'OUT'],
#  [104, 'знаю', 'знать', 'V', 'V,несов,пе=непрош,ед,изъяв,1-л', 'OUT'],
#  [104, 'алису', 'алиса', 'S', 'S,имя,жен,од=вин,ед', 'OUT'],
#  [104, 'подумывал', 'подумывать', 'V', 'V,несов,нп=прош,ед,изъяв,муж', 'OUT'],
#  [104, 'засесть', 'засаживаться', 'V', 'V,нп=инф,сов', 'OUT'],
#  [104,
#   'солидный',
#   'солидный',
#   'A=m',
#   'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)',
#   'OUT'],
#  [104, 'ученый', 'ученый', 'A=m', 'S,муж,од=им,ед', 'OUT'],
#  [104, 'труд', 'труд', 'S', 'S,муж,неод=(вин,ед|им,ед)', 'OUT'],
#  [104, 'названием', 'название', 'S', 'S,сред,неод=твор,ед', 'OUT'],
#  [104, 'вопросу', 'вопрос', 'S', 'S,муж,неод=дат,ед', 'OUT'],
#  [104, 'причинах', 'причина', 'S', 'S,жен,неод=пр,мн', 'OUT'],
#  [104,
#   'непереводимости',
#   'непереводимость',
#   'S',
#   'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)',
#   'OUT'],
#  [104,
#   'русский',
#   'русский',
#   'A=m',
#   'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)',
#   'OUT'],
#  [104, 'язык', 'язык', 'S', 'S,муж,неод=(вин,ед|им,ед)', 'OUT'],
#  [104, 'сказки', 'сказка', 'S', 'S,жен,неод=(вин,мн|род,ед|им,мн)', 'OUT'],
#  [104, 'льюиса', 'льюис', 'S', 'S,гео,муж,неод=род,ед', 'OUT'],
#  [104, 'кэрролла', 'кэрролл', 'S', 'S,фам,муж,од=(вин,ед|род,ед)', 'OUT'],
#  [105,
#   'прекрасный',
#   'прекрасный',
#   'A=m',
#   'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)',
#   'OUT'],
#  [105, 'день', 'день', 'S', 'S,муж,неод=(вин,ед|им,ед)', 'OUT'],
#  [105, 'прочитал', 'прочитывать', 'V', 'V=прош,ед,изъяв,муж,сов', 'OUT'],
#  [105, 'письмо', 'письмо', 'S', 'S,сред,неод=(вин,ед|им,ед)', 'OUT'],
#  [105, 'льюиса', 'льюис', 'S', 'S,гео,муж,неод=род,ед', 'OUT'],
#  [105, 'кэрролла', 'кэрролл', 'S', 'S,фам,муж,од=(вин,ед|род,ед)', 'OUT'],
#  [105,
#   'театральному',
#   'театральный',
#   'A-PRO=m',
#   'A=(дат,ед,полн,муж|дат,ед,полн,сред)',
#   'OUT'],
#  [105, 'режиссеру', 'режиссер', 'V', 'S,муж,од=дат,ед', 'OUT'],
#  [105,
#   'который',
#   'который',
#   'A-PRO=m',
#   'APRO=(вин,ед,муж,неод|им,ед,муж)',
#   'OUT'],
#  [105, 'решил', 'решать', 'V', 'V,пе=прош,ед,изъяв,муж,сов', 'OUT'],
#  [105, 'поставить', 'поставлять', 'V', 'V,пе=инф,сов', 'OUT'],
#  [105, 'сказку', 'сказка', 'S', 'S,жен,неод=вин,ед', 'OUT'],
#  [105, 'алису', 'алиса', 'S', 'S,имя,жен,од=вин,ед', 'OUT'],
#  [105, 'сцене', 'сцена', 'S', 'S,жен,неод=(пр,ед|дат,ед)', 'OUT'],
#  [106,
#   'говорилось',
#   'говориться',
#   'V',
#   'V,несов,нп=прош,ед,изъяв,сред',
#   'OUT'],
#  [107, 'видел', 'видеть', 'V', 'V,несов,пе=прош,ед,изъяв,муж', 'OUT'],
#  [107, 'алиса', 'алиса', 'S', 'S,имя,жен,од=им,ед', 'OUT'],
#  [107, 'своем', 'свой', 'V', 'APRO=(пр,ед,муж|пр,ед,сред)', 'OUT'],
#  [107, 'воображении', 'воображение', 'S', 'S,сред,неод=пр,ед', 'OUT'],
#  [107,
#   'любящая',
#   'любить',
#   'V',
#   'V,несов,пе=непрош,им,ед,прич,полн,жен,действ',
#   'OUT'],
#  [107, 'это', 'это', 'S-PRO', 'PART=', 'OUT'],
#  [107, 'прежде', 'прежде', 'ADV', 'PR=', 'OUT'],
#  [107, 'любящая', 'любящий', 'V', 'A=им,ед,полн,жен', 'OUT'],
#  [107, 'нежная', 'нежный', 'A=f', 'A=им,ед,полн,жен', 'OUT'],
#  [107, 'нежная', 'нежный', 'A=f', 'A=им,ед,полн,жен', 'OUT'],
#  [107, 'лань', 'лань', 'V', 'S,жен,од=(вин,ед|им,ед)', 'OUT'],
#  [107,
#   'любящая',
#   'любить',
#   'V',
#   'V,несов,пе=непрош,им,ед,прич,полн,жен,действ',
#   'OUT'],
#  [107, 'собака', 'собака', 'S', 'S,жен,од=им,ед', 'OUT'],
#  [107,
#   'простите',
#   'прощать',
#   'V',
#   'V=(непрош,мн,изъяв,2-л,сов|мн,пов,2-л,сов)',
#   'OUT'],
#  [107,
#   'прозаическое',
#   'прозаический',
#   'A=n',
#   'A=(вин,ед,полн,сред|им,ед,полн,сред)',
#   'OUT'],
#  [107, 'сравнение', 'сравнение', 'S', 'S,сред,неод=(вин,ед|им,ед)', 'OUT'],
#  [107, 'знаю', 'знать', 'V', 'V,несов,пе=непрош,ед,изъяв,1-л', 'OUT'],
#  [107, 'земле', 'земля', 'S', 'S,жен,неод=(пр,ед|дат,ед)', 'OUT'],
#  [107,
#   'любви',
#   'любовь',
#   'S',
#   'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)',
#   'OUT'],
#  [107, 'чище', 'чистый', 'A=comp', 'A=срав', 'OUT'],
#  [107, 'совершенней', 'совершенный', 'A=f', 'A=срав', 'OUT'],
#  [107, 'учтивая', 'учтивый', 'V', 'A=им,ед,полн,жен', 'OUT'],
#  [107, 'вежливая', 'вежливый', 'V', 'A=им,ед,полн,жен', 'OUT'],
#  [107, 'приветливая', 'приветливый', 'A=f', 'A=им,ед,полн,жен', 'OUT'],
#  [107, 'всеми', 'все', 'S-PRO', 'SPRO,мн=твор', 'OUT'],
#  [107, 'великими', 'великий', 'A=pl', 'A=твор,мн,полн', 'OUT'],
#  [107, 'малыми', 'малый', 'A=pl', 'A=твор,мн,полн', 'OUT'],
#  [107, 'могучими', 'могучий', 'A=pl', 'A=твор,мн,полн', 'OUT'],
#  [107, 'смешными', 'смешной', 'A=pl', 'A=твор,мн,полн', 'OUT'],
#  [107, 'королями', 'король', 'S', 'S,муж,од=твор,мн', 'OUT'],
#  [107, 'червяками', 'червяк', 'S', 'S,муж,од=твор,мн', 'OUT'],
#  [107, 'словно', 'словно', 'CONJ', 'CONJ=', 'OUT'],
#  [107, 'сама', 'сам', 'A-PRO=f', 'APRO=им,ед,жен', 'OUT'],
#  [107, 'королевская', 'королевский', 'A=f', 'A=им,ед,полн,жен', 'OUT'],
#  [107, 'дочь', 'дочь', 'S', 'S,жен,од=(вин,ед|им,ед)', 'OUT'],
#  [107, 'шитом', 'шитый', 'S', 'A=(пр,ед,полн,муж|пр,ед,полн,сред)', 'OUT'],
#  [107, 'золотом', 'золотой', 'V', 'A=(пр,ед,полн,муж|пр,ед,полн,сред)', 'OUT'],
#  [107, 'наряде', 'наряд', 'ADV', 'S,муж,неод=пр,ед', 'OUT'],
#  [108, 'доверчивая', 'доверчивый', 'A=f', 'A=им,ед,полн,жен', 'OUT'],
#  [108, 'готовая', 'готовый', 'A=f', 'A=им,ед,полн,жен', 'OUT'],
#  [108, 'поверить', 'поверять', 'V', 'V=инф,сов', 'OUT'],
#  [108, 'самую', 'самый', 'A-PRO=f', 'APRO=вин,ед,жен', 'OUT'],
#  [108, 'невозможную', 'невозможный', 'A=f', 'A=вин,ед,полн,жен', 'OUT'],
#  [108, 'небыль', 'небыль', 'ADV', 'S,жен,неод=(вин,ед|им,ед)', 'OUT'],
#  [108, 'принять', 'принимать', 'V', 'V=инф,сов', 'OUT'],
#  [108,
#   'безграничным',
#   'безграничный',
#   'A=pl',
#   'A=(дат,мн,полн|твор,ед,полн,муж|твор,ед,полн,сред)',
#   'OUT'],
#  [108, 'доверием', 'доверие', 'S', 'S,сред,неод=твор,ед', 'OUT'],
#  [108,
#   'мечтательницы',
#   'мечтательница',
#   'S',
#   'S,жен,од=(род,ед|им,мн)',
#   'OUT'],
#  [108, 'любопытная', 'любопытный', 'A=f', 'A=им,ед,полн,жен', 'OUT'],
#  [108, 'отчаянно', 'отчаянно', 'ADV', 'ADV=', 'OUT'],
#  [108, 'любопытная', 'любопытный', 'A=f', 'A=им,ед,полн,жен', 'OUT'],
#  [108, 'жизнерадостная', 'жизнерадостный', 'A=f', 'A=им,ед,полн,жен', 'OUT'],
#  [108,
#   'той',
#   'тот',
#   'A-PRO=f',
#   'APRO=(пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен)',
#   'OUT'],
#  [108,
#   'жизнерадостностью',
#   'жизнерадостность',
#   'S',
#   'S,жен,неод=твор,ед',
#   'OUT'],
#  [108, 'дается', 'даваться', 'V', 'V,нп=непрош,ед,изъяв,3-л,несов', 'OUT'],
#  [108, 'лишь', 'лишь', 'PART', 'PART=', 'OUT'],
#  [108, 'детстве', 'детство', 'S', 'S,сред,неод=пр,ед', 'OUT'],
#  [108, 'весь', 'весь', 'A-PRO=m', 'APRO=(вин,ед,муж,неод|им,ед,муж)', 'OUT'],
#  [108, 'мир', 'мир', 'S', 'S,муж,неод=(вин,ед|им,ед)', 'OUT'],
#  [108, 'нов', 'новый', 'S', 'A=ед,кр,муж', 'OUT'],
#  [108, 'прекрасен', 'прекрасный', 'A=m', 'A=ед,кр,муж', 'OUT'],
#  [108, 'горе', 'горе', 'S', 'S,ед,сред,неод=(пр|вин|им)', 'OUT'],
#  [108, 'грех', 'грех', 'S', 'S,муж,неод=(вин,ед|им,ед)', 'OUT'],
#  [108, 'лишь', 'лишь', 'PART', 'PART=', 'OUT'],
#  [108, 'слова', 'слово', 'S', 'S,сред,неод=(вин,мн|род,ед|им,мн)', 'OUT'],
#  [108, 'пустые', 'пустой', 'A=pl', 'A=(вин,мн,полн,неод|им,мн,полн)', 'OUT'],
#  [108, 'звуки', 'звук', 'S', 'S,муж,неод=(вин,мн|им,мн)', 'OUT'],
#  [108,
#   'означающие',
#   'означать',
#   'V',
#   'V,пе=(непрош,им,мн,прич,полн,несов,действ|непрош,вин,мн,прич,полн,несов,действ,неод)',
#   'OUT'],
#  [108, 'знаю', 'знать', 'V', 'V,несов,пе=непрош,ед,изъяв,1-л', 'OUT'],
#  [108, 'почему', 'почему', 'ADV-PRO', 'ADVPRO=', 'OUT'],
#  [108, 'прочитал', 'прочитывать', 'V', 'V=прош,ед,изъяв,муж,сов', 'OUT'],
#  [108, 'это', 'этот', 'S-PRO', 'APRO=(вин,ед,сред|им,ед,сред)', 'OUT'],
#  [108, 'письмо', 'письмо', 'S', 'S,сред,неод=(вин,ед|им,ед)', 'OUT'],
#  [108, 'захотелось', 'захотеться', 'V', 'V,сов,нп=прош,ед,изъяв,сред', 'OUT'],
#  [108, 'познакомились', 'познакомиться', 'V', 'V,сов,нп=прош,мн,изъяв', 'OUT'],
#  [108,
#   'прелестной',
#   'прелестный',
#   'A=f',
#   'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)',
#   'OUT'],
#  [108, 'девочкой', 'девочка', 'A=f', 'S,жен,од=твор,ед', 'OUT'],
#  [108, 'махнул', 'махнуть', 'V', 'V,сов,нп=прош,ед,изъяв,муж', 'OUT'],
#  [108, 'рукой', 'рука', 'S', 'S,жен,неод=твор,ед', 'OUT'],
#  [108, 'свой', 'свой', 'A-PRO=m', 'APRO=(вин,ед,муж,неод|им,ед,муж)', 'OUT'],
#  [108,
#   'научный',
#   'научный',
#   'A=sg',
#   'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)',
#   'OUT'],
#  [108, 'труд', 'труд', 'S', 'S,муж,неод=(вин,ед|им,ед)', 'OUT'],
#  [108, 'свои', 'свой', 'A-PRO=pl', 'APRO=(им,мн|вин,мн,неод)', 'OUT'],
#  [108, 'умные', 'умный', 'A=pl', 'A=(вин,мн,полн,неод|им,мн,полн)', 'OUT'],
#  [108,
#   'рассуждения',
#   'рассуждение',
#   'S',
#   'S,сред,неод=(вин,мн|род,ед|им,мн)',
#   'OUT'],
#  [108, 'решил', 'решать', 'V', 'V,пе=прош,ед,изъяв,муж,сов', 'OUT'],
#  [108, 'попробовать', 'попробовать', 'V', 'V,сов,пе=инф', 'OUT'],
#  [108, 'попробовать', 'попробовать', 'V', 'V,сов,пе=инф', 'OUT'],
#  [108, 'рассказать', 'рассказывать', 'V', 'V=инф,сов', 'OUT'],
#  [108, 'по-русски', 'по-русски', 'ADV', 'ADV=', 'OUT'],
#  [109, 'вскоре', 'вскоре', 'ADV', 'ADV=', 'OUT'],
#  [109, 'понял', 'понимать', 'V', 'V=прош,ед,изъяв,муж,сов', 'OUT'],
#  [109, 'самое', 'самый', 'A-PRO=n', 'APRO=(вин,ед,сред|им,ед,сред)', 'OUT'],
#  [109, 'главное', 'главное', 'A=n', 'S,сред,неод=(вин,ед|им,ед)', 'OUT'],
#  [109, 'книжке', 'книжка', 'S', 'S,жен,неод=(пр,ед|дат,ед)', 'OUT'],
#  [109, 'алисе', 'алиса', 'S', 'S,имя,жен,од=(пр,ед|дат,ед)', 'OUT'],
#  [109, 'загадки', 'загадка', 'S', 'S,жен,неод=(вин,мн|род,ед|им,мн)', 'OUT'],
#  [109, 'фокусы', 'фокус', 'S', 'S,муж,неод=(вин,мн|им,мн)', 'OUT'],
#  [109,
#   'головоломки',
#   'головоломка',
#   'S',
#   'S,жен,неод=(вин,мн|род,ед|им,мн)',
#   'OUT'],
#  [109, 'игра', 'игра', 'S', 'S,жен,неод=им,ед', 'OUT'],
#  [109, 'слов', 'слово', 'S', 'S,сред,неод=род,мн', 'OUT'],
#  [109, 'блистательная', 'блистательный', 'A=f', 'A=им,ед,полн,жен', 'OUT'],
#  [109, 'игра', 'игра', 'S', 'S,жен,неод=им,ед', 'OUT'],
#  [109, 'ума', 'ум', 'S', 'S,муж,неод=род,ед', 'OUT'],
#  [110, 'сама', 'сам', 'A-PRO=f', 'APRO=им,ед,жен', 'OUT'],
#  [110, 'алиса', 'алиса', 'S', 'S,имя,жен,од=им,ед', 'OUT'],
#  [111, 'маленькая', 'маленький', 'A=f', 'A=им,ед,полн,жен', 'OUT'],
#  [111, 'алиса', 'алиса', 'S', 'S,имя,жен,од=им,ед', 'OUT'],
#  [111, 'которую', 'который', 'A-PRO=f', 'APRO=вин,ед,жен', 'OUT'],
#  [111, 'автор', 'автор', 'S', 'S,муж,од=им,ед', 'OUT'],
#  [111, 'любит', 'любить', 'V', 'V,несов,пе=непрош,ед,изъяв,3-л', 'OUT'],
#  [111, 'порой', 'пора', 'S', 'S,жен,неод=твор,ед', 'OUT'],
#  [111,
#   'посмеивается',
#   'посмеиваться',
#   'V',
#   'V,несов,нп=непрош,ед,изъяв,3-л',
#   'OUT'],
#  [111, 'эта', 'этот', 'A-PRO=f', 'APRO=им,ед,жен', 'OUT'],
#  [111, 'великая', 'великий', 'A=f', 'A=им,ед,полн,жен', 'OUT'],
#  [111, 'любовь', 'любовь', 'S', 'S,жен,неод=(вин,ед|им,ед)', 'OUT'],
#  [111,
#   'превращает',
#   'превращать',
#   'V',
#   'V,пе=непрош,ед,изъяв,3-л,несов',
#   'OUT'],
#  [111, 'фокусы', 'фокус', 'S', 'S,муж,неод=(вин,мн|им,мн)', 'OUT'],
#  [111, 'чудеса', 'чудо', 'S', 'S,сред,неод=(вин,мн|им,мн)', 'OUT'],
#  [111, 'фокусника', 'фокусник', 'S', 'S,муж,од=(вин,ед|род,ед)', 'OUT'],
#  [111, 'волшебника', 'волшебник', 'S', 'S,муж,од=(вин,ед|род,ед)', 'OUT'],
#  [112,
#   'настоящий',
#   'настоящий',
#   'A=m',
#   'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)',
#   'OUT'],
#  [112, 'волшебник', 'волшебник', 'S', 'S,муж,од=им,ед', 'OUT'],
#  [112, 'подарить', 'подарить', 'V', 'V,сов,пе=инф', 'OUT'],
#  [112, 'девочке', 'девочка', 'S', 'S,жен,од=(пр,ед|дат,ед)', 'OUT'],
#  [112, 'сказке', 'сказка', 'S', 'S,жен,неод=(пр,ед|дат,ед)', 'OUT'],
#  [113, 'такую', 'такой', 'A-PRO=f', 'APRO=вин,ед,жен', 'OUT'],
#  [113, 'долгую', 'долгий', 'A=f', 'A=вин,ед,полн,жен', 'OUT'],
#  [113, 'долгую', 'долгий', 'A=f', 'A=вин,ед,полн,жен', 'OUT'],
#  [113, 'века', 'век', 'S', 'S,муж,неод=(вин,мн|род,ед|им,мн)', 'OUT'],
#  [113, 'жизнь', 'жизнь', 'S', 'S,жен,неод=(вин,ед|им,ед)', 'OUT'],
#  [114, 'словом', 'словом', 'PARENTH', 'ADV,вводн=', 'OUT'],
#  [114, 'мной', 'я', 'S-PRO', 'SPRO,ед,1-л=твор', 'OUT'],
#  [114, 'вышло', 'выходить', 'V', 'V,нп=прош,ед,изъяв,сред,сов', 'OUT'],
#  [114, 'точь-в-точь', 'точь-в-точь', 'ADV', 'ADV=', 'OUT'],
#  [114,
#   'одной',
#   'один',
#   'ANUM=f',
#   'APRO=(пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен)',
#   'OUT'],
#  ...]
